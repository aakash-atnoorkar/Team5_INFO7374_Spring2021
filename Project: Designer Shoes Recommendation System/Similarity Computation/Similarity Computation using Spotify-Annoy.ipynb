# %%
import pandas as pd
import urllib.request
import os

# %%
filtered_shoes = pd.read_csv('filtered_shoes_1.csv')
df = filtered_shoes[:10000]

# %%
base_dir = os.path.join(os.getcwd())
images_dir = os.path.join(base_dir, 'images')

# %%
error_indices = {}
for index, row in df.iterrows():
    try:
        print(index)
        picture_file = os.path.join(images_dir, str(row['id']) + '.jpg')
        urllib.request.urlretrieve(row['image_url'], picture_file)
    except Exception as e:
        print('error: ', index)
        error_indices[index] = row['id']

# %%
import tensorflow_hub as hub
from annoy import AnnoyIndex
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import tensorflow as tf
import tensorflow_hub as hub
# For saving 'feature vectors' into a txt file
import numpy as np
# Glob for reading file names in a folder
import glob
import os.path
from tqdm import tqdm
import ntpath
import warnings
import cv2
from annoy import AnnoyIndex
from scipy import spatial
warnings.filterwarnings('ignore')
from operator import itemgetter

# %%
def load_img(path):
    # Reads the image file and returns data type of string
    img = tf.io.read_file(path)
    # Decodes the image to W x H x 3 shape tensor with type of uint8
    img = tf.io.decode_jpeg(img, channels=3)
    # Resizes the image to 224 x 224 x 3 shape tensor
    img = tf.image.resize_with_pad(img, 224, 224)
    # Converts the data type of uint8 to float32 by adding a new axis
    # img becomes 1 x 224 x 224 x 3 tensor with data type of float32
    # This is required for the mobilenet model we are using
    img = tf.image.convert_image_dtype(img,tf.float32)[tf.newaxis, ...]

    return img

# %%
def match_id(filename):
    product_id = '_'.join(filename.split('_')[:-1])
    return product_id

# %%
def get_features(img, image_path): 
     # Definition of module with using tfhub.dev
    module_handle = "https://tfhub.dev/google/imagenet/mobilenet_v2_140_224/feature_vector/4"
    # Loads the module
    module = hub.load(module_handle)
    features = module(img)
    # Remove single-dimensional entries from the 'features' array  
    feature_set = np.squeeze(features)
    #print(image_path)

    # Saves the image feature vectors into a file for later use
    outfile_name = os.path.basename(image_path) + ".npz"

    out_path = os.path.join('C:/Users/Aakash Atnoorkar/Documents/ADM/Final Project/images/imagesScraped/',outfile_name)
    # Saves the 'feature_set' to a text file
    np.savetxt(out_path, feature_set, delimiter=',')
    vector = np.loadtxt(out_path)
    #image_style_embeddings[ntpath.basename(image_path)] = vector
    return vector

# %%
image_paths= glob.glob('C:\\Users\\Aakash Atnoorkar\\Documents\\ADM\\Final Project\\images\\*.jpg')
#vectorfiles = glob.glob('C:\\Users\\Aakash Atnoorkar\\Documents\\ADM\\Assignment 3\\images_test\\ImagesScraped\\*.npz')
# compute styles
image_style_embeddings = {}


for image_path in tqdm(image_paths): 
    image_tensor = load_img(image_path)
    vector = get_features(image_tensor, image_path)
    image_style_embeddings[ntpath.basename(image_path)] = vector

# %%
def cluster():
    print("-------Annoy Index Generation----------------")
    # Defining data structures as empty dict
    file_index_to_file_name = {}
    file_index_to_file_vector = {}
    file_index_to_product_id = {}
    # Configuring annoy parameters
    dims = 1792
    n_nearest_neighbors = 20
    trees = 10000
    # Reads all file names which stores feature vectors
    allfiles = glob.glob('C:\\Users\\Aakash Atnoorkar\\Documents\\ADM\\Final Project\\images\\imagesScraped\\*.npz')

    t = AnnoyIndex(dims, metric='angular')
    
    for file_index, i in enumerate(allfiles):
    # Reads feature vectors and assigns them into the file_vector 
        file_vector = np.loadtxt(i)

        # Assigns file_name, feature_vectors and corresponding product_id
        file_name = os.path.basename(i).split('.')[0]
        print(file_name)
        file_index_to_file_name[file_index] = file_name
        file_index_to_file_vector[file_index] = file_vector
        file_index_to_product_id[file_index] = file_name

        # Adds image feature vectors into annoy index   
        t.add_item(file_index, file_vector)

        print("---------------------------------")
        print("Annoy index     : %s" %file_index)
        print("Image file name : %s" %file_name)
        print("Product id      : %s" %file_index_to_product_id[file_index])
        #print("--- %.2f minutes passed ---------" % ((time.time() - start_time)/60))


    # Builds annoy index
    t.build(trees)

    print ("Step.1 - ANNOY index generation - Finished")
    print ("Step.2 - Similarity score calculation - Started ") 
  
    global named_nearest_neighbors
    named_nearest_neighbors = []

  # Loops through all indexed items
    for i in file_index_to_file_name.keys():

    # Assigns master file_name, image feature vectors and product id values
        master_file_name = file_index_to_file_name[i]
        master_vector = file_index_to_file_vector[i]
        master_product_id = file_index_to_product_id[i]

        # Calculates the nearest neighbors of the master item
        nearest_neighbors = t.get_nns_by_item(i, n_nearest_neighbors)

        # Loops through the nearest neighbors of the master item
        for j in nearest_neighbors:

            # Assigns file_name, image feature vectors and product id values of the similar item
            neighbor_file_name = file_index_to_file_name[j]
            neighbor_file_vector = file_index_to_file_vector[j]
            neighbor_product_id = file_index_to_product_id[j]

            # Calculates the similarity score of the similar item
            similarity = 1 - spatial.distance.cosine(master_vector, neighbor_file_vector)
            rounded_similarity = int((similarity * 10000)) / 10000.0

            # Appends master product id with the similarity score 
            # and the product id of the similar items
            named_nearest_neighbors.append({
            'similarity': rounded_similarity,
            'master_pi': master_product_id,
            'similar_pi': neighbor_product_id})
#     print(named_nearest_neighbors)
#     print(type(named_nearest_neighbors))
            
#     return named_nearest_neighbors

# %%
image_paths = glob.glob('C:\\Users\\Aakash Atnoorkar\\Documents\\ADM\\Final Project\\images\\*.jpg')
print(f'Founnd [{len(image_paths)}] images')

images = []
index = 1
for image_path in image_paths:
    image = cv2.imread(image_path, 3)
    b,g,r = cv2.split(image)           # get b, g, r
    image = cv2.merge([r,g,b])         # switch it to r, g, b
    image = cv2.resize(image, (200, 200))
    product_id = ntpath.basename(image_path).split('.')[0]
    images.append({
      'image_path' : ntpath.basename(image_path),
        'image' : image,
       'product_id':product_id
    })
    print(index)
    index += 1

# %%
cluster()
# Out:
# -------Annoy Index Generation----------------
# AV-9hndsuC1rwyj_g2bb
# ---------------------------------
# Annoy index     : 0
# Image file name : AV-9hndsuC1rwyj_g2bb
# Product id      : AV-9hndsuC1rwyj_g2bb
# AV-9hpHjYSSHbkXwpyGV
# ---------------------------------
# Annoy index     : 1
# Image file name : AV-9hpHjYSSHbkXwpyGV
# Product id      : AV-9hpHjYSSHbkXwpyGV
# AV-9hqJYuC1rwyj_g2c_
# ---------------------------------
# Annoy index     : 2
# Image file name : AV-9hqJYuC1rwyj_g2c_
# Product id      : AV-9hqJYuC1rwyj_g2c_
# AV-9hriAuC1rwyj_g2dv
# ---------------------------------
# Annoy index     : 3
# Image file name : AV-9hriAuC1rwyj_g2dv
# Product id      : AV-9hriAuC1rwyj_g2dv
# AV-9hsUluC1rwyj_g2eA
# ---------------------------------
# Annoy index     : 4
# Image file name : AV-9hsUluC1rwyj_g2eA
# Product id      : AV-9hsUluC1rwyj_g2eA
# AV-9id7QYSSHbkXwpyLI
# ---------------------------------
# Annoy index     : 5
# Image file name : AV-9id7QYSSHbkXwpyLI
# Product id      : AV-9id7QYSSHbkXwpyLI
# AV-9iKxlYSSHbkXwpyKu
# ---------------------------------
# Annoy index     : 6
# Image file name : AV-9iKxlYSSHbkXwpyKu
# Product id      : AV-9iKxlYSSHbkXwpyKu
# AV-9jSoSHh53nbDR_pU4
# ---------------------------------
# Annoy index     : 7
# Image file name : AV-9jSoSHh53nbDR_pU4
# Product id      : AV-9jSoSHh53nbDR_pU4
# AV-9jwmYHh53nbDR_pVm
# ---------------------------------
# Annoy index     : 8
# Image file name : AV-9jwmYHh53nbDR_pVm
# Product id      : AV-9jwmYHh53nbDR_pVm
# AV-9luQ5Hh53nbDR_pWA
# ---------------------------------
# Annoy index     : 9
# Image file name : AV-9luQ5Hh53nbDR_pWA
# Product id      : AV-9luQ5Hh53nbDR_pWA
# AV-KM264uC1rwyj_gSfJ
# ---------------------------------
# Annoy index     : 10
# Image file name : AV-KM264uC1rwyj_gSfJ
# Product id      : AV-KM264uC1rwyj_gSfJ
# AV-KM4DlKZqtpbFMSpKi
# ---------------------------------
# Annoy index     : 11
# Image file name : AV-KM4DlKZqtpbFMSpKi
# Product id      : AV-KM4DlKZqtpbFMSpKi
# AV-KM5O-uC1rwyj_gShN
# ---------------------------------
# Annoy index     : 12
# Image file name : AV-KM5O-uC1rwyj_gShN
# Product id      : AV-KM5O-uC1rwyj_gShN
# AV-KM6rLYSSHbkXwpOPy
# ---------------------------------
# Annoy index     : 13
# Image file name : AV-KM6rLYSSHbkXwpOPy
# Product id      : AV-KM6rLYSSHbkXwpOPy
# AV-KM9V2uC1rwyj_gSl1
# ---------------------------------
# Annoy index     : 14
# Image file name : AV-KM9V2uC1rwyj_gSl1
# Product id      : AV-KM9V2uC1rwyj_gSl1
# AV-KMgNFYSSHbkXwpN8t
# ---------------------------------
# Annoy index     : 15
# Image file name : AV-KMgNFYSSHbkXwpN8t
# Product id      : AV-KMgNFYSSHbkXwpN8t
# AV-KMhBWYSSHbkXwpN9Z
# ---------------------------------
# Annoy index     : 16
# Image file name : AV-KMhBWYSSHbkXwpN9Z
# Product id      : AV-KMhBWYSSHbkXwpN9Z
# AV-KMkFyHh53nbDR_KlQ
# ---------------------------------
# Annoy index     : 17
# Image file name : AV-KMkFyHh53nbDR_KlQ
# Product id      : AV-KMkFyHh53nbDR_KlQ
# AV-KMlJ4KZqtpbFMSo99
# ---------------------------------
# Annoy index     : 18
# Image file name : AV-KMlJ4KZqtpbFMSo99
# Product id      : AV-KMlJ4KZqtpbFMSo99
# AV-KMlNJHh53nbDR_Kl4
# ---------------------------------
# Annoy index     : 19
# Image file name : AV-KMlNJHh53nbDR_Kl4
# Product id      : AV-KMlNJHh53nbDR_Kl4
# AV-KMloCHh53nbDR_Kmj
# ---------------------------------
# Annoy index     : 20
# Image file name : AV-KMloCHh53nbDR_Kmj
# Product id      : AV-KMloCHh53nbDR_Kmj
# AV-KMnWFuC1rwyj_gSU4
# ---------------------------------
# Annoy index     : 21
# Image file name : AV-KMnWFuC1rwyj_gSU4
# Product id      : AV-KMnWFuC1rwyj_gSU4
# AV-KMpWUKZqtpbFMSpBr
# ---------------------------------
# Annoy index     : 22
# Image file name : AV-KMpWUKZqtpbFMSpBr
# Product id      : AV-KMpWUKZqtpbFMSpBr
# AV-KMpYyHh53nbDR_Kpd
# ---------------------------------
# Annoy index     : 23
# Image file name : AV-KMpYyHh53nbDR_Kpd
# Product id      : AV-KMpYyHh53nbDR_Kpd
# AV-KM_DKYSSHbkXwpOVZ
# ---------------------------------
# Annoy index     : 24
# Image file name : AV-KM_DKYSSHbkXwpOVZ
# Product id      : AV-KM_DKYSSHbkXwpOVZ
# AV-KNDMeKZqtpbFMSpPe
# ---------------------------------
# Annoy index     : 25
# Image file name : AV-KNDMeKZqtpbFMSpPe
# Product id      : AV-KNDMeKZqtpbFMSpPe
# AV-KNDYHuC1rwyj_gSqf
# ---------------------------------
# Annoy index     : 26
# Image file name : AV-KNDYHuC1rwyj_gSqf
# Product id      : AV-KNDYHuC1rwyj_gSqf
# AV-nb1kGKZqtpbFMSzjO
# ---------------------------------
# Annoy index     : 27
# Image file name : AV-nb1kGKZqtpbFMSzjO
# Product id      : AV-nb1kGKZqtpbFMSzjO
# AV-nb3nPuC1rwyj_gea6
# ---------------------------------
# Annoy index     : 28
# Image file name : AV-nb3nPuC1rwyj_gea6
# Product id      : AV-nb3nPuC1rwyj_gea6
# AV-nb3Y2KZqtpbFMSzkZ
# ---------------------------------
# Annoy index     : 29
# Image file name : AV-nb3Y2KZqtpbFMSzkZ
# Product id      : AV-nb3Y2KZqtpbFMSzkZ
# AV-nb4hWYSSHbkXwpaCH
# ---------------------------------
# Annoy index     : 30
# Image file name : AV-nb4hWYSSHbkXwpaCH
# Product id      : AV-nb4hWYSSHbkXwpaCH
# AV-nb4rjuC1rwyj_gebo
# ---------------------------------
# Annoy index     : 31
# Image file name : AV-nb4rjuC1rwyj_gebo
# Product id      : AV-nb4rjuC1rwyj_gebo
# AV-nbamiYSSHbkXwpZrw
# ---------------------------------
# Annoy index     : 32
# Image file name : AV-nbamiYSSHbkXwpZrw
# Product id      : AV-nbamiYSSHbkXwpZrw
# AV-nbbEYKZqtpbFMSzOi
# ---------------------------------
# Annoy index     : 33
# Image file name : AV-nbbEYKZqtpbFMSzOi
# Product id      : AV-nbbEYKZqtpbFMSzOi
# AV-nbbkmKZqtpbFMSzPC
# ---------------------------------
# Annoy index     : 34
# Image file name : AV-nbbkmKZqtpbFMSzPC
# Product id      : AV-nbbkmKZqtpbFMSzPC
# AV-nbbPIHh53nbDR_Uqy
# ---------------------------------
# Annoy index     : 35
# Image file name : AV-nbbPIHh53nbDR_Uqy
# Product id      : AV-nbbPIHh53nbDR_Uqy
# AV-nbbryuC1rwyj_geFh
# ---------------------------------
# Annoy index     : 36
# Image file name : AV-nbbryuC1rwyj_geFh
# Product id      : AV-nbbryuC1rwyj_geFh
# AV-nbdonHh53nbDR_Usf
# ---------------------------------
# Annoy index     : 37
# Image file name : AV-nbdonHh53nbDR_Usf
# Product id      : AV-nbdonHh53nbDR_Usf
# AV-nbk4_uC1rwyj_geM-
# ---------------------------------
# Annoy index     : 38
# Image file name : AV-nbk4_uC1rwyj_geM-
# Product id      : AV-nbk4_uC1rwyj_geM-
# AV-nbkfLHh53nbDR_Uxo
# ---------------------------------
# Annoy index     : 39
# Image file name : AV-nbkfLHh53nbDR_Uxo
# Product id      : AV-nbkfLHh53nbDR_Uxo
# AV-nbkV9Hh53nbDR_Uxh
# ---------------------------------
# Annoy index     : 40
# Image file name : AV-nbkV9Hh53nbDR_Uxh
# Product id      : AV-nbkV9Hh53nbDR_Uxh
# AV-nblQfHh53nbDR_Uyf
# ---------------------------------
# Annoy index     : 41
# Image file name : AV-nblQfHh53nbDR_Uyf
# Product id      : AV-nblQfHh53nbDR_Uyf
# AV-nbLQOHh53nbDR_Ugl
# ---------------------------------
# Annoy index     : 42
# Image file name : AV-nbLQOHh53nbDR_Ugl
# Product id      : AV-nbLQOHh53nbDR_Ugl
# AV-nblWguC1rwyj_geNW
# ---------------------------------
# Annoy index     : 43
# Image file name : AV-nblWguC1rwyj_geNW
# Product id      : AV-nblWguC1rwyj_geNW
# AV-nbMCiYSSHbkXwpZh8
# ---------------------------------
# Annoy index     : 44
# Image file name : AV-nbMCiYSSHbkXwpZh8
# Product id      : AV-nbMCiYSSHbkXwpZh8
# AV-nbnIEKZqtpbFMSzYa
# ---------------------------------
# Annoy index     : 45
# Image file name : AV-nbnIEKZqtpbFMSzYa
# Product id      : AV-nbnIEKZqtpbFMSzYa
# AV-nbouDuC1rwyj_gePn
# ---------------------------------
# Annoy index     : 46
# Image file name : AV-nbouDuC1rwyj_gePn
# Product id      : AV-nbouDuC1rwyj_gePn
# AV-nbp72Hh53nbDR_U1w
# ---------------------------------
# Annoy index     : 47
# Image file name : AV-nbp72Hh53nbDR_U1w
# Product id      : AV-nbp72Hh53nbDR_U1w
# AV-nbPnBKZqtpbFMSzHi
# ---------------------------------
# Annoy index     : 48
# Image file name : AV-nbPnBKZqtpbFMSzHi
# Product id      : AV-nbPnBKZqtpbFMSzHi
# AV-nbQfOKZqtpbFMSzII
# ---------------------------------
# Annoy index     : 49
# Image file name : AV-nbQfOKZqtpbFMSzII
# Product id      : AV-nbQfOKZqtpbFMSzII
# AV-nbR8_YSSHbkXwpZmH
# ---------------------------------
# Annoy index     : 50
# Image file name : AV-nbR8_YSSHbkXwpZmH
# Product id      : AV-nbR8_YSSHbkXwpZmH
# AV-nbSQpKZqtpbFMSzJP
# ---------------------------------
# Annoy index     : 51
# Image file name : AV-nbSQpKZqtpbFMSzJP
# Product id      : AV-nbSQpKZqtpbFMSzJP
# AV-nbszEKZqtpbFMSzc4
# ---------------------------------
# Annoy index     : 52
# Image file name : AV-nbszEKZqtpbFMSzc4
# Product id      : AV-nbszEKZqtpbFMSzc4
# AV-nbtKeKZqtpbFMSzdO
# ---------------------------------
# Annoy index     : 53
# Image file name : AV-nbtKeKZqtpbFMSzdO
# Product id      : AV-nbtKeKZqtpbFMSzdO
# AV-nbWZWHh53nbDR_Un7
# ---------------------------------
# Annoy index     : 54
# Image file name : AV-nbWZWHh53nbDR_Un7
# Product id      : AV-nbWZWHh53nbDR_Un7
# AV-nbYC9Hh53nbDR_Uob
# ---------------------------------
# Annoy index     : 55
# Image file name : AV-nbYC9Hh53nbDR_Uob
# Product id      : AV-nbYC9Hh53nbDR_Uob
# AV-nc1HpHh53nbDR_Vj9
# ---------------------------------
# Annoy index     : 56
# Image file name : AV-nc1HpHh53nbDR_Vj9
# Product id      : AV-nc1HpHh53nbDR_Vj9
# AV-ncA5QYSSHbkXwpaFB
# ---------------------------------
# Annoy index     : 57
# Image file name : AV-ncA5QYSSHbkXwpaFB
# Product id      : AV-ncA5QYSSHbkXwpaFB
# AV-ncB20uC1rwyj_gefo
# ---------------------------------
# Annoy index     : 58
# Image file name : AV-ncB20uC1rwyj_gefo
# Product id      : AV-ncB20uC1rwyj_gefo
# AV-ncBjdYSSHbkXwpaFz
# ---------------------------------
# Annoy index     : 59
# Image file name : AV-ncBjdYSSHbkXwpaFz
# Product id      : AV-ncBjdYSSHbkXwpaFz
# AV-ncCT1Hh53nbDR_VEo
# ---------------------------------
# Annoy index     : 60
# Image file name : AV-ncCT1Hh53nbDR_VEo
# Product id      : AV-ncCT1Hh53nbDR_VEo
# AV-ncFjJHh53nbDR_VHC
# ---------------------------------
# Annoy index     : 61
# Image file name : AV-ncFjJHh53nbDR_VHC
# Product id      : AV-ncFjJHh53nbDR_VHC
# AV-ncGkUHh53nbDR_VIH
# ---------------------------------
# Annoy index     : 62
# Image file name : AV-ncGkUHh53nbDR_VIH
# Product id      : AV-ncGkUHh53nbDR_VIH
# AV-ncGQTuC1rwyj_geid
# ---------------------------------
# Annoy index     : 63
# Image file name : AV-ncGQTuC1rwyj_geid
# Product id      : AV-ncGQTuC1rwyj_geid
# AV-nciAjuC1rwyj_geyX
# ---------------------------------
# Annoy index     : 64
# Image file name : AV-nciAjuC1rwyj_geyX
# Product id      : AV-nciAjuC1rwyj_geyX
# AV-ncJi-uC1rwyj_gekx
# ---------------------------------
# Annoy index     : 65
# Image file name : AV-ncJi-uC1rwyj_gekx
# Product id      : AV-ncJi-uC1rwyj_gekx
# AV-ncL2WuC1rwyj_gemu
# ---------------------------------
# Annoy index     : 66
# Image file name : AV-ncL2WuC1rwyj_gemu
# Product id      : AV-ncL2WuC1rwyj_gemu
# AV-ncM9VHh53nbDR_VMe
# ---------------------------------
# Annoy index     : 67
# Image file name : AV-ncM9VHh53nbDR_VMe
# Product id      : AV-ncM9VHh53nbDR_VMe
# AV-ncPiuuC1rwyj_gepk
# ---------------------------------
# Annoy index     : 68
# Image file name : AV-ncPiuuC1rwyj_gepk
# Product id      : AV-ncPiuuC1rwyj_gepk
# AV-ncQLSuC1rwyj_geqO
# ---------------------------------
# Annoy index     : 69
# Image file name : AV-ncQLSuC1rwyj_geqO
# Product id      : AV-ncQLSuC1rwyj_geqO
# AV-ncqVLYSSHbkXwpaec
# ---------------------------------
# Annoy index     : 70
# Image file name : AV-ncqVLYSSHbkXwpaec
# Product id      : AV-ncqVLYSSHbkXwpaec
# AV-ncrrVuC1rwyj_ge34
# ---------------------------------
# Annoy index     : 71
# Image file name : AV-ncrrVuC1rwyj_ge34
# Product id      : AV-ncrrVuC1rwyj_ge34
# AV-nct2MuC1rwyj_ge4_
# ---------------------------------
# Annoy index     : 72
# Image file name : AV-nct2MuC1rwyj_ge4_
# Product id      : AV-nct2MuC1rwyj_ge4_
# AV-ncuedYSSHbkXwpahG
# ---------------------------------
# Annoy index     : 73
# Image file name : AV-ncuedYSSHbkXwpahG
# Product id      : AV-ncuedYSSHbkXwpahG
# AV-ncuMfHh53nbDR_Vej
# ---------------------------------
# Annoy index     : 74
# Image file name : AV-ncuMfHh53nbDR_Vej
# Product id      : AV-ncuMfHh53nbDR_Vej
# AV-ncVUwHh53nbDR_VSu
# ---------------------------------
# Annoy index     : 75
# Image file name : AV-ncVUwHh53nbDR_VSu
# Product id      : AV-ncVUwHh53nbDR_VSu
# AV-ncWJ6YSSHbkXwpaV-
# ---------------------------------
# Annoy index     : 76
# Image file name : AV-ncWJ6YSSHbkXwpaV-
# Product id      : AV-ncWJ6YSSHbkXwpaV-
# AV-ncxHHKZqtpbFMS0F5
# ---------------------------------
# Annoy index     : 77
# Image file name : AV-ncxHHKZqtpbFMS0F5
# Product id      : AV-ncxHHKZqtpbFMS0F5
# AV-ncxniKZqtpbFMS0GX
# ---------------------------------
# Annoy index     : 78
# Image file name : AV-ncxniKZqtpbFMS0GX
# Product id      : AV-ncxniKZqtpbFMS0GX
# AV-ncXxXHh53nbDR_VVC
# ---------------------------------
# Annoy index     : 79
# Image file name : AV-ncXxXHh53nbDR_VVC
# Product id      : AV-ncXxXHh53nbDR_VVC
# AV-ndG1uKZqtpbFMS0SV
# ---------------------------------
# Annoy index     : 80
# Image file name : AV-ndG1uKZqtpbFMS0SV
# Product id      : AV-ndG1uKZqtpbFMS0SV
# AV-ndGnvKZqtpbFMS0SG
# ---------------------------------
# Annoy index     : 81
# Image file name : AV-ndGnvKZqtpbFMS0SG
# Product id      : AV-ndGnvKZqtpbFMS0SG
# AV-ndHk9KZqtpbFMS0S5
# ---------------------------------
# Annoy index     : 82
# Image file name : AV-ndHk9KZqtpbFMS0S5
# Product id      : AV-ndHk9KZqtpbFMS0S5
# AV-ndHZmYSSHbkXwpawS
# ---------------------------------
# Annoy index     : 83
# Image file name : AV-ndHZmYSSHbkXwpawS
# Product id      : AV-ndHZmYSSHbkXwpawS
# AV14CA98vKc47QAVnx6N
# ---------------------------------
# Annoy index     : 84
# Image file name : AV14CA98vKc47QAVnx6N
# Product id      : AV14CA98vKc47QAVnx6N
# AV1c53Wl-jtxr-f31d0J
# ---------------------------------
# Annoy index     : 85
# Image file name : AV1c53Wl-jtxr-f31d0J
# Product id      : AV1c53Wl-jtxr-f31d0J
# AV2A4MxtvKc47QAVol_G
# ---------------------------------
# Annoy index     : 86
# Image file name : AV2A4MxtvKc47QAVol_G
# Product id      : AV2A4MxtvKc47QAVol_G
# AV2cVsE7vKc47QAVpJKS
# ---------------------------------
# Annoy index     : 87
# Image file name : AV2cVsE7vKc47QAVpJKS
# Product id      : AV2cVsE7vKc47QAVpJKS
# AV2cZ7SYGV-KLJ3al3p6
# ---------------------------------
# Annoy index     : 88
# Image file name : AV2cZ7SYGV-KLJ3al3p6
# Product id      : AV2cZ7SYGV-KLJ3al3p6
# AV2cZiLFvKc47QAVpJgp
# ---------------------------------
# Annoy index     : 89
# Image file name : AV2cZiLFvKc47QAVpJgp
# Product id      : AV2cZiLFvKc47QAVpJgp
# AV2cZrmXglJLPUi8Ql2c
# ---------------------------------
# Annoy index     : 90
# Image file name : AV2cZrmXglJLPUi8Ql2c
# Product id      : AV2cZrmXglJLPUi8Ql2c
# AV2vVlavglJLPUi8QyKq
# ---------------------------------
# Annoy index     : 91
# Image file name : AV2vVlavglJLPUi8QyKq
# Product id      : AV2vVlavglJLPUi8QyKq
# AV2vVlI4GV-KLJ3amD7P
# ---------------------------------
# Annoy index     : 92
# Image file name : AV2vVlI4GV-KLJ3amD7P
# Product id      : AV2vVlI4GV-KLJ3amD7P
# AV3E8hOd-jtxr-f3-my_
# ---------------------------------
# Annoy index     : 93
# Image file name : AV3E8hOd-jtxr-f3-my_
# Product id      : AV3E8hOd-jtxr-f3-my_
# AV4itgAI-jtxr-f3AIix
# ---------------------------------
# Annoy index     : 94
# Image file name : AV4itgAI-jtxr-f3AIix
# Product id      : AV4itgAI-jtxr-f3AIix
# AV50Jgvy-jtxr-f3ILyv
# ---------------------------------
# Annoy index     : 95
# Image file name : AV50Jgvy-jtxr-f3ILyv
# Product id      : AV50Jgvy-jtxr-f3ILyv
# AV5AX2S5GV-KLJ3asXKP
# ---------------------------------
# Annoy index     : 96
# Image file name : AV5AX2S5GV-KLJ3asXKP
# Product id      : AV5AX2S5GV-KLJ3asXKP
# AV5AX_fdglJLPUi8XQk8
# ---------------------------------
# Annoy index     : 97
# Image file name : AV5AX_fdglJLPUi8XQk8
# Product id      : AV5AX_fdglJLPUi8XQk8
# AV5AYAMO-jtxr-f3Du5h
# ---------------------------------
# Annoy index     : 98
# Image file name : AV5AYAMO-jtxr-f3Du5h
# Product id      : AV5AYAMO-jtxr-f3Du5h
# AV5yuGub-jtxr-f3ICRO
# ---------------------------------
# Annoy index     : 99
# Image file name : AV5yuGub-jtxr-f3ICRO
# Product id      : AV5yuGub-jtxr-f3ICRO
# AVpe3xOJLJeJML43xIBp
# ---------------------------------
# Annoy index     : 100
# Image file name : AVpe3xOJLJeJML43xIBp
# Product id      : AVpe3xOJLJeJML43xIBp
# AVpe43DzilAPnD_xQIjE
# ---------------------------------
# Annoy index     : 101
# Image file name : AVpe43DzilAPnD_xQIjE
# Product id      : AVpe43DzilAPnD_xQIjE
# AVpe43H3LJeJML43xkBD
# ---------------------------------
# Annoy index     : 102
# Image file name : AVpe43H3LJeJML43xkBD
# Product id      : AVpe43H3LJeJML43xkBD
# AVpe4eCqilAPnD_xP-yc
# ---------------------------------
# Annoy index     : 103
# Image file name : AVpe4eCqilAPnD_xP-yc
# Product id      : AVpe4eCqilAPnD_xP-yc
# AVpe4HOr1cnluZ0-Yydy
# ---------------------------------
# Annoy index     : 104
# Image file name : AVpe4HOr1cnluZ0-Yydy
# Product id      : AVpe4HOr1cnluZ0-Yydy
# AVpe4WbILJeJML43xXRS
# ---------------------------------
# Annoy index     : 105
# Image file name : AVpe4WbILJeJML43xXRS
# Product id      : AVpe4WbILJeJML43xXRS
# AVpe56NT1cnluZ0-Zey_
# ---------------------------------
# Annoy index     : 106
# Image file name : AVpe56NT1cnluZ0-Zey_
# Product id      : AVpe56NT1cnluZ0-Zey_
# AVpe5Ssl1cnluZ0-ZP9z
# ---------------------------------
# Annoy index     : 107
# Image file name : AVpe5Ssl1cnluZ0-ZP9z
# Product id      : AVpe5Ssl1cnluZ0-ZP9z
# AVpe80zfilAPnD_xRmAo
# ---------------------------------
# Annoy index     : 108
# Image file name : AVpe80zfilAPnD_xRmAo
# Product id      : AVpe80zfilAPnD_xRmAo
# AVpe8ltm1cnluZ0-adgq
# ---------------------------------
# Annoy index     : 109
# Image file name : AVpe8ltm1cnluZ0-adgq
# Product id      : AVpe8ltm1cnluZ0-adgq
# AVpe8Pi0ilAPnD_xRYTs
# ---------------------------------
# Annoy index     : 110
# Image file name : AVpe8Pi0ilAPnD_xRYTs
# Product id      : AVpe8Pi0ilAPnD_xRYTs
# AVpe9CG6LJeJML43zGfm
# ---------------------------------
# Annoy index     : 111
# Image file name : AVpe9CG6LJeJML43zGfm
# Product id      : AVpe9CG6LJeJML43zGfm
# AVpe9ZxsilAPnD_xRzci
# ---------------------------------
# Annoy index     : 112
# Image file name : AVpe9ZxsilAPnD_xRzci
# Product id      : AVpe9ZxsilAPnD_xRzci
# AVpe_2h81cnluZ0-boAU
# ---------------------------------
# Annoy index     : 113
# Image file name : AVpe_2h81cnluZ0-boAU
# Product id      : AVpe_2h81cnluZ0-boAU
# AVpe_gumilAPnD_xSjIb
# ---------------------------------
# Annoy index     : 114
# Image file name : AVpe_gumilAPnD_xSjIb
# Product id      : AVpe_gumilAPnD_xSjIb
# AVpe_hnpLJeJML43z_Gv
# ---------------------------------
# Annoy index     : 115
# Image file name : AVpe_hnpLJeJML43z_Gv
# Product id      : AVpe_hnpLJeJML43z_Gv
# AVpf-kgK1cnluZ0-ubpu
# ---------------------------------
# Annoy index     : 116
# Image file name : AVpf-kgK1cnluZ0-ubpu
# Product id      : AVpf-kgK1cnluZ0-ubpu
# AVpf0mS0ilAPnD_xi50b
# ---------------------------------
# Annoy index     : 117
# Image file name : AVpf0mS0ilAPnD_xi50b
# Product id      : AVpf0mS0ilAPnD_xi50b
# AVpf1ASPLJeJML43Ee-a
# ---------------------------------
# Annoy index     : 118
# Image file name : AVpf1ASPLJeJML43Ee-a
# Product id      : AVpf1ASPLJeJML43Ee-a
# AVpf1Y3ailAPnD_xjIF2
# ---------------------------------
# Annoy index     : 119
# Image file name : AVpf1Y3ailAPnD_xjIF2
# Product id      : AVpf1Y3ailAPnD_xjIF2
# AVpf355ailAPnD_xjzWL
# ---------------------------------
# Annoy index     : 120
# Image file name : AVpf355ailAPnD_xjzWL
# Product id      : AVpf355ailAPnD_xjzWL
# AVpf38PKLJeJML43FRwO
# ---------------------------------
# Annoy index     : 121
# Image file name : AVpf38PKLJeJML43FRwO
# Product id      : AVpf38PKLJeJML43FRwO
# AVpf3kCgilAPnD_xjtkp
# ---------------------------------
# Annoy index     : 122
# Image file name : AVpf3kCgilAPnD_xjtkp
# Product id      : AVpf3kCgilAPnD_xjtkp
# AVpf44T8LJeJML43Fgy6
# ---------------------------------
# Annoy index     : 123
# Image file name : AVpf44T8LJeJML43Fgy6
# Product id      : AVpf44T8LJeJML43Fgy6
# AVpf4QnhilAPnD_xj5BW
# ---------------------------------
# Annoy index     : 124
# Image file name : AVpf4QnhilAPnD_xj5BW
# Product id      : AVpf4QnhilAPnD_xj5BW
# AVpf51qXilAPnD_xkSHI
# ---------------------------------
# Annoy index     : 125
# Image file name : AVpf51qXilAPnD_xkSHI
# Product id      : AVpf51qXilAPnD_xkSHI
# AVpf566silAPnD_xkTWM
# ---------------------------------
# Annoy index     : 126
# Image file name : AVpf566silAPnD_xkTWM
# Product id      : AVpf566silAPnD_xkTWM
# AVpfaMRwLJeJML438uZ4
# ---------------------------------
# Annoy index     : 127
# Image file name : AVpfaMRwLJeJML438uZ4
# Product id      : AVpfaMRwLJeJML438uZ4
# AVpfArORLJeJML430Zbv
# ---------------------------------
# Annoy index     : 128
# Image file name : AVpfArORLJeJML430Zbv
# Product id      : AVpfArORLJeJML430Zbv
# AVpfb1BSilAPnD_xbuFf
# ---------------------------------
# Annoy index     : 129
# Image file name : AVpfb1BSilAPnD_xbuFf
# Product id      : AVpfb1BSilAPnD_xbuFf
# AVpfBEW3LJeJML430iQ5
# ---------------------------------
# Annoy index     : 130
# Image file name : AVpfBEW3LJeJML430iQ5
# Product id      : AVpfBEW3LJeJML430iQ5
# AVpfBgBmLJeJML430sYG
# ---------------------------------
# Annoy index     : 131
# Image file name : AVpfBgBmLJeJML430sYG
# Product id      : AVpfBgBmLJeJML430sYG
# AVpfBsxCLJeJML430w57
# ---------------------------------
# Annoy index     : 132
# Image file name : AVpfBsxCLJeJML430w57
# Product id      : AVpfBsxCLJeJML430w57
# AVpfBuTrilAPnD_xTVnQ
# ---------------------------------
# Annoy index     : 133
# Image file name : AVpfBuTrilAPnD_xTVnQ
# Product id      : AVpfBuTrilAPnD_xTVnQ
# AVpfc2AwLJeJML439b8c
# ---------------------------------
# Annoy index     : 134
# Image file name : AVpfc2AwLJeJML439b8c
# Product id      : AVpfc2AwLJeJML439b8c
# AVpfcFTl1cnluZ0-kxe4
# ---------------------------------
# Annoy index     : 135
# Image file name : AVpfcFTl1cnluZ0-kxe4
# Product id      : AVpfcFTl1cnluZ0-kxe4
# AVpfCI881cnluZ0-ccYD
# ---------------------------------
# Annoy index     : 136
# Image file name : AVpfCI881cnluZ0-ccYD
# Product id      : AVpfCI881cnluZ0-ccYD
# AVpfCLDsLJeJML4307of
# ---------------------------------
# Annoy index     : 137
# Image file name : AVpfCLDsLJeJML4307of
# Product id      : AVpfCLDsLJeJML4307of
# AVpfDAttilAPnD_xTxZP
# ---------------------------------
# Annoy index     : 138
# Image file name : AVpfDAttilAPnD_xTxZP
# Product id      : AVpfDAttilAPnD_xTxZP
# AVpfDqWyLJeJML431bqP
# ---------------------------------
# Annoy index     : 139
# Image file name : AVpfDqWyLJeJML431bqP
# Product id      : AVpfDqWyLJeJML431bqP
# AVpfEFx41cnluZ0-dGzz
# ---------------------------------
# Annoy index     : 140
# Image file name : AVpfEFx41cnluZ0-dGzz
# Product id      : AVpfEFx41cnluZ0-dGzz
# AVpfESj9LJeJML431p8l
# ---------------------------------
# Annoy index     : 141
# Image file name : AVpfESj9LJeJML431p8l
# Product id      : AVpfESj9LJeJML431p8l
# AVpfeWdJ1cnluZ0-lXYU
# ---------------------------------
# Annoy index     : 142
# Image file name : AVpfeWdJ1cnluZ0-lXYU
# Product id      : AVpfeWdJ1cnluZ0-lXYU
# AVpffFGE1cnluZ0-lkTg
# ---------------------------------
# Annoy index     : 143
# Image file name : AVpffFGE1cnluZ0-lkTg
# Product id      : AVpffFGE1cnluZ0-lkTg
# AVpfgC0D1cnluZ0-l2ba
# ---------------------------------
# Annoy index     : 144
# Image file name : AVpfgC0D1cnluZ0-l2ba
# Product id      : AVpfgC0D1cnluZ0-l2ba
# AVpfgjYYLJeJML43-dZQ
# ---------------------------------
# Annoy index     : 145
# Image file name : AVpfgjYYLJeJML43-dZQ
# Product id      : AVpfgjYYLJeJML43-dZQ
# AVpfgL_JLJeJML43-WoR
# ---------------------------------
# Annoy index     : 146
# Image file name : AVpfgL_JLJeJML43-WoR
# Product id      : AVpfgL_JLJeJML43-WoR
# AVpfGpVAilAPnD_xVBZI
# ---------------------------------
# Annoy index     : 147
# Image file name : AVpfGpVAilAPnD_xVBZI
# Product id      : AVpfGpVAilAPnD_xVBZI
# AVpfgvfk1cnluZ0-mDPa
# ---------------------------------
# Annoy index     : 148
# Image file name : AVpfgvfk1cnluZ0-mDPa
# Product id      : AVpfgvfk1cnluZ0-mDPa
# AVpfGWT3ilAPnD_xU7MQ
# ---------------------------------
# Annoy index     : 149
# Image file name : AVpfGWT3ilAPnD_xU7MQ
# Product id      : AVpfGWT3ilAPnD_xU7MQ
# AVpfHSRh1cnluZ0-eM3-
# ---------------------------------
# Annoy index     : 150
# Image file name : AVpfHSRh1cnluZ0-eM3-
# Product id      : AVpfHSRh1cnluZ0-eM3-
# AVpfHwJS1cnluZ0-eWuG
# ---------------------------------
# Annoy index     : 151
# Image file name : AVpfHwJS1cnluZ0-eWuG
# Product id      : AVpfHwJS1cnluZ0-eWuG
# AVpfI7W01cnluZ0-ewgE
# ---------------------------------
# Annoy index     : 152
# Image file name : AVpfI7W01cnluZ0-ewgE
# Product id      : AVpfI7W01cnluZ0-ewgE
# AVpfIFEz1cnluZ0-edya
# ---------------------------------
# Annoy index     : 153
# Image file name : AVpfIFEz1cnluZ0-edya
# Product id      : AVpfIFEz1cnluZ0-edya
# AVpfIZ7HLJeJML433DNk
# ---------------------------------
# Annoy index     : 154
# Image file name : AVpfIZ7HLJeJML433DNk
# Product id      : AVpfIZ7HLJeJML433DNk
# AVpfJ8INLJeJML433kPP
# ---------------------------------
# Annoy index     : 155
# Image file name : AVpfJ8INLJeJML433kPP
# Product id      : AVpfJ8INLJeJML433kPP
# AVpfjAMzilAPnD_xduD1
# ---------------------------------
# Annoy index     : 156
# Image file name : AVpfjAMzilAPnD_xduD1
# Product id      : AVpfjAMzilAPnD_xduD1
# AVpfJkLrLJeJML433cY1
# ---------------------------------
# Annoy index     : 157
# Image file name : AVpfJkLrLJeJML433cY1
# Product id      : AVpfJkLrLJeJML433cY1
# AVpfJvGBilAPnD_xWDz5
# ---------------------------------
# Annoy index     : 158
# Image file name : AVpfJvGBilAPnD_xWDz5
# Product id      : AVpfJvGBilAPnD_xWDz5
# AVpfk-Q81cnluZ0-nUsT
# ---------------------------------
# Annoy index     : 159
# Image file name : AVpfk-Q81cnluZ0-nUsT
# Product id      : AVpfk-Q81cnluZ0-nUsT
# AVpfk9jZ1cnluZ0-nUd_
# ---------------------------------
# Annoy index     : 160
# Image file name : AVpfk9jZ1cnluZ0-nUd_
# Product id      : AVpfk9jZ1cnluZ0-nUd_
# AVpfKjuI1cnluZ0-fS-R
# ---------------------------------
# Annoy index     : 161
# Image file name : AVpfKjuI1cnluZ0-fS-R
# Product id      : AVpfKjuI1cnluZ0-fS-R
# AVpfKK0CilAPnD_xWM4n
# ---------------------------------
# Annoy index     : 162
# Image file name : AVpfKK0CilAPnD_xWM4n
# Product id      : AVpfKK0CilAPnD_xWM4n
# AVpfkRRWLJeJML43_kSj
# ---------------------------------
# Annoy index     : 163
# Image file name : AVpfkRRWLJeJML43_kSj
# Product id      : AVpfkRRWLJeJML43_kSj
# AVpfLJG6ilAPnD_xWhQV
# ---------------------------------
# Annoy index     : 164
# Image file name : AVpfLJG6ilAPnD_xWhQV
# Product id      : AVpfLJG6ilAPnD_xWhQV
# AVpfLrzQLJeJML434JFY
# ---------------------------------
# Annoy index     : 165
# Image file name : AVpfLrzQLJeJML434JFY
# Product id      : AVpfLrzQLJeJML434JFY
# AVpfLXyhilAPnD_xWmNc
# ---------------------------------
# Annoy index     : 166
# Image file name : AVpfLXyhilAPnD_xWmNc
# Product id      : AVpfLXyhilAPnD_xWmNc
# AVpfmz_71cnluZ0-n4iA
# ---------------------------------
# Annoy index     : 167
# Image file name : AVpfmz_71cnluZ0-n4iA
# Product id      : AVpfmz_71cnluZ0-n4iA
# AVpfn5s3LJeJML43ArJE
# ---------------------------------
# Annoy index     : 168
# Image file name : AVpfn5s3LJeJML43ArJE
# Product id      : AVpfn5s3LJeJML43ArJE
# AVpfN8eKLJeJML4344Sm
# ---------------------------------
# Annoy index     : 169
# Image file name : AVpfN8eKLJeJML4344Sm
# Product id      : AVpfN8eKLJeJML4344Sm
# AVpfNaNailAPnD_xXQmH
# ---------------------------------
# Annoy index     : 170
# Image file name : AVpfNaNailAPnD_xXQmH
# Product id      : AVpfNaNailAPnD_xXQmH
# AVpfNmIELJeJML434w4b
# ---------------------------------
# Annoy index     : 171
# Image file name : AVpfNmIELJeJML434w4b
# Product id      : AVpfNmIELJeJML434w4b
# AVpfNSw4LJeJML434qaO
# ---------------------------------
# Annoy index     : 172
# Image file name : AVpfNSw4LJeJML434qaO
# Product id      : AVpfNSw4LJeJML434qaO
# AVpfNujoilAPnD_xXXc1
# ---------------------------------
# Annoy index     : 173
# Image file name : AVpfNujoilAPnD_xXXc1
# Product id      : AVpfNujoilAPnD_xXXc1
# AVpfO0ww1cnluZ0-gszN
# ---------------------------------
# Annoy index     : 174
# Image file name : AVpfO0ww1cnluZ0-gszN
# Product id      : AVpfO0ww1cnluZ0-gszN
# AVpfOFMeilAPnD_xXe5b
# ---------------------------------
# Annoy index     : 175
# Image file name : AVpfOFMeilAPnD_xXe5b
# Product id      : AVpfOFMeilAPnD_xXe5b
# AVpfOKIw1cnluZ0-ge0t
# ---------------------------------
# Annoy index     : 176
# Image file name : AVpfOKIw1cnluZ0-ge0t
# Product id      : AVpfOKIw1cnluZ0-ge0t
# AVpfOq3SilAPnD_xXrNj
# ---------------------------------
# Annoy index     : 177
# Image file name : AVpfOq3SilAPnD_xXrNj
# Product id      : AVpfOq3SilAPnD_xXrNj
# AVpfPswDilAPnD_xYAsQ
# ---------------------------------
# Annoy index     : 178
# Image file name : AVpfPswDilAPnD_xYAsQ
# Product id      : AVpfPswDilAPnD_xYAsQ
# AVpfPsWnLJeJML435dGO
# ---------------------------------
# Annoy index     : 179
# Image file name : AVpfPsWnLJeJML435dGO
# Product id      : AVpfPsWnLJeJML435dGO
# AVpfrB5f1cnluZ0-pIhw
# ---------------------------------
# Annoy index     : 180
# Image file name : AVpfrB5f1cnluZ0-pIhw
# Product id      : AVpfrB5f1cnluZ0-pIhw
# AVpfRBkB1cnluZ0-hbT-
# ---------------------------------
# Annoy index     : 181
# Image file name : AVpfRBkB1cnluZ0-hbT-
# Product id      : AVpfRBkB1cnluZ0-hbT-
# AVpfRkJsLJeJML436EP8
# ---------------------------------
# Annoy index     : 182
# Image file name : AVpfRkJsLJeJML436EP8
# Product id      : AVpfRkJsLJeJML436EP8
# AVpfroreilAPnD_xgUSE
# ---------------------------------
# Annoy index     : 183
# Image file name : AVpfroreilAPnD_xgUSE
# Product id      : AVpfroreilAPnD_xgUSE
# AVpfR_m31cnluZ0-hu0N
# ---------------------------------
# Annoy index     : 184
# Image file name : AVpfR_m31cnluZ0-hu0N
# Product id      : AVpfR_m31cnluZ0-hu0N
# AVpfs1zNilAPnD_xgqjh
# ---------------------------------
# Annoy index     : 185
# Image file name : AVpfs1zNilAPnD_xgqjh
# Product id      : AVpfs1zNilAPnD_xgqjh
# AVpfSPKr1cnluZ0-hzpz
# ---------------------------------
# Annoy index     : 186
# Image file name : AVpfSPKr1cnluZ0-hzpz
# Product id      : AVpfSPKr1cnluZ0-hzpz
# AVpfstKl1cnluZ0-poJ4
# ---------------------------------
# Annoy index     : 187
# Image file name : AVpfstKl1cnluZ0-poJ4
# Product id      : AVpfstKl1cnluZ0-poJ4
# AVpfSwNzilAPnD_xY_tB
# ---------------------------------
# Annoy index     : 188
# Image file name : AVpfSwNzilAPnD_xY_tB
# Product id      : AVpfSwNzilAPnD_xY_tB
# AVpfTMqFLJeJML436lYL
# ---------------------------------
# Annoy index     : 189
# Image file name : AVpfTMqFLJeJML436lYL
# Product id      : AVpfTMqFLJeJML436lYL
# AVpftPCILJeJML43CPOU
# ---------------------------------
# Annoy index     : 190
# Image file name : AVpftPCILJeJML43CPOU
# Product id      : AVpftPCILJeJML43CPOU
# AVpftVqF1cnluZ0-pz7V
# ---------------------------------
# Annoy index     : 191
# Image file name : AVpftVqF1cnluZ0-pz7V
# Product id      : AVpftVqF1cnluZ0-pz7V
# AVpfTzZP1cnluZ0-iUZw
# ---------------------------------
# Annoy index     : 192
# Image file name : AVpfTzZP1cnluZ0-iUZw
# Product id      : AVpfTzZP1cnluZ0-iUZw
# AVpfu7zILJeJML43Cv4y
# ---------------------------------
# Annoy index     : 193
# Image file name : AVpfu7zILJeJML43Cv4y
# Product id      : AVpfu7zILJeJML43Cv4y
# AVpfueNW1cnluZ0-qKJu
# ---------------------------------
# Annoy index     : 194
# Image file name : AVpfueNW1cnluZ0-qKJu
# Product id      : AVpfueNW1cnluZ0-qKJu
# AVpfuGBsLJeJML43Cf-l
# ---------------------------------
# Annoy index     : 195
# Image file name : AVpfuGBsLJeJML43Cf-l
# Product id      : AVpfuGBsLJeJML43Cf-l
# AVpfUP3K1cnluZ0-ieCo
# ---------------------------------
# Annoy index     : 196
# Image file name : AVpfUP3K1cnluZ0-ieCo
# Product id      : AVpfUP3K1cnluZ0-ieCo
# AVpfwad2LJeJML43DKCI
# ---------------------------------
# Annoy index     : 197
# Image file name : AVpfwad2LJeJML43DKCI
# Product id      : AVpfwad2LJeJML43DKCI
# AVpfwdpXilAPnD_xhtaX
# ---------------------------------
# Annoy index     : 198
# Image file name : AVpfwdpXilAPnD_xhtaX
# Product id      : AVpfwdpXilAPnD_xhtaX
# AVpfWLtyilAPnD_xaGle
# ---------------------------------
# Annoy index     : 199
# Image file name : AVpfWLtyilAPnD_xaGle
# Product id      : AVpfWLtyilAPnD_xaGle
# AVpfxoUZ1cnluZ0-rDzl
# ---------------------------------
# Annoy index     : 200
# Image file name : AVpfxoUZ1cnluZ0-rDzl
# Product id      : AVpfxoUZ1cnluZ0-rDzl
# AVpfXUPPLJeJML4375Sd
# ---------------------------------
# Annoy index     : 201
# Image file name : AVpfXUPPLJeJML4375Sd
# Product id      : AVpfXUPPLJeJML4375Sd
# AVpfYD6lilAPnD_xaq5W
# ---------------------------------
# Annoy index     : 202
# Image file name : AVpfYD6lilAPnD_xaq5W
# Product id      : AVpfYD6lilAPnD_xaq5W
# AVpfYeJaLJeJML438Phi
# ---------------------------------
# Annoy index     : 203
# Image file name : AVpfYeJaLJeJML438Phi
# Product id      : AVpfYeJaLJeJML438Phi
# AVpfYrg_1cnluZ0-j11Q
# ---------------------------------
# Annoy index     : 204
# Image file name : AVpfYrg_1cnluZ0-j11Q
# Product id      : AVpfYrg_1cnluZ0-j11Q
# AVpfZ5NBLJeJML438pa6
# ---------------------------------
# Annoy index     : 205
# Image file name : AVpfZ5NBLJeJML438pa6
# Product id      : AVpfZ5NBLJeJML438pa6
# AVpfZaja1cnluZ0-kDgB
# ---------------------------------
# Annoy index     : 206
# Image file name : AVpfZaja1cnluZ0-kDgB
# Product id      : AVpfZaja1cnluZ0-kDgB
# AVpfZKMY1cnluZ0-j-0e
# ---------------------------------
# Annoy index     : 207
# Image file name : AVpfZKMY1cnluZ0-j-0e
# Product id      : AVpfZKMY1cnluZ0-j-0e
# AVpfZQMWLJeJML438d-N
# ---------------------------------
# Annoy index     : 208
# Image file name : AVpfZQMWLJeJML438d-N
# Product id      : AVpfZQMWLJeJML438d-N
# AVpfZWseilAPnD_xbDEn
# ---------------------------------
# Annoy index     : 209
# Image file name : AVpfZWseilAPnD_xbDEn
# Product id      : AVpfZWseilAPnD_xbDEn
# AVpg1oEYLJeJML43TYKw
# ---------------------------------
# Annoy index     : 210
# Image file name : AVpg1oEYLJeJML43TYKw
# Product id      : AVpg1oEYLJeJML43TYKw
# AVpg4CQEilAPnD_xyXLi
# ---------------------------------
# Annoy index     : 211
# Image file name : AVpg4CQEilAPnD_xyXLi
# Product id      : AVpg4CQEilAPnD_xyXLi
# AVpg4tTH1cnluZ0-7irp
# ---------------------------------
# Annoy index     : 212
# Image file name : AVpg4tTH1cnluZ0-7irp
# Product id      : AVpg4tTH1cnluZ0-7irp
# AVpg8zZXilAPnD_xzT49
# ---------------------------------
# Annoy index     : 213
# Image file name : AVpg8zZXilAPnD_xzT49
# Product id      : AVpg8zZXilAPnD_xzT49
# AVpg9iYo1cnluZ0-8hIj
# ---------------------------------
# Annoy index     : 214
# Image file name : AVpg9iYo1cnluZ0-8hIj
# Product id      : AVpg9iYo1cnluZ0-8hIj
# AVpg9Jr2ilAPnD_xzYfH
# ---------------------------------
# Annoy index     : 215
# Image file name : AVpg9Jr2ilAPnD_xzYfH
# Product id      : AVpg9Jr2ilAPnD_xzYfH
# AVpg9jtyLJeJML43U9Cz
# ---------------------------------
# Annoy index     : 216
# Image file name : AVpg9jtyLJeJML43U9Cz
# Product id      : AVpg9jtyLJeJML43U9Cz
# AVpgac9KLJeJML43NlCB
# ---------------------------------
# Annoy index     : 217
# Image file name : AVpgac9KLJeJML43NlCB
# Product id      : AVpgac9KLJeJML43NlCB
# AVpgBzl41cnluZ0-vSQf
# ---------------------------------
# Annoy index     : 218
# Image file name : AVpgBzl41cnluZ0-vSQf
# Product id      : AVpgBzl41cnluZ0-vSQf
# AVpgC5JGilAPnD_xmjOg
# ---------------------------------
# Annoy index     : 219
# Image file name : AVpgC5JGilAPnD_xmjOg
# Product id      : AVpgC5JGilAPnD_xmjOg
# AVpgCaoO1cnluZ0-vcHn
# ---------------------------------
# Annoy index     : 220
# Image file name : AVpgCaoO1cnluZ0-vcHn
# Product id      : AVpgCaoO1cnluZ0-vcHn
# AVpgD0W8ilAPnD_xmzPp
# ---------------------------------
# Annoy index     : 221
# Image file name : AVpgD0W8ilAPnD_xmzPp
# Product id      : AVpgD0W8ilAPnD_xmzPp
# AVpgEr5R1cnluZ0-wCbS
# ---------------------------------
# Annoy index     : 222
# Image file name : AVpgEr5R1cnluZ0-wCbS
# Product id      : AVpgEr5R1cnluZ0-wCbS
# AVpgHw5xilAPnD_xnyLN
# ---------------------------------
# Annoy index     : 223
# Image file name : AVpgHw5xilAPnD_xnyLN
# Product id      : AVpgHw5xilAPnD_xnyLN
# AVpgjEXmLJeJML43Pcl2
# ---------------------------------
# Annoy index     : 224
# Image file name : AVpgjEXmLJeJML43Pcl2
# Product id      : AVpgjEXmLJeJML43Pcl2
# AVpgjiQF1cnluZ0-3HN4
# ---------------------------------
# Annoy index     : 225
# Image file name : AVpgjiQF1cnluZ0-3HN4
# Product id      : AVpgjiQF1cnluZ0-3HN4
# AVpgjXbkilAPnD_xuCc8
# ---------------------------------
# Annoy index     : 226
# Image file name : AVpgjXbkilAPnD_xuCc8
# Product id      : AVpgjXbkilAPnD_xuCc8
# AVpgk1tdLJeJML43P2cT
# ---------------------------------
# Annoy index     : 227
# Image file name : AVpgk1tdLJeJML43P2cT
# Product id      : AVpgk1tdLJeJML43P2cT
# AVpgn-k0LJeJML43Qjkj
# ---------------------------------
# Annoy index     : 228
# Image file name : AVpgn-k0LJeJML43Qjkj
# Product id      : AVpgn-k0LJeJML43Qjkj
# AVpgNGD6ilAPnD_xpAke
# ---------------------------------
# Annoy index     : 229
# Image file name : AVpgNGD6ilAPnD_xpAke
# Product id      : AVpgNGD6ilAPnD_xpAke
# AVpgOcmuilAPnD_xpVft
# ---------------------------------
# Annoy index     : 230
# Image file name : AVpgOcmuilAPnD_xpVft
# Product id      : AVpgOcmuilAPnD_xpVft
# AVpgptyp1cnluZ0-4hXT
# ---------------------------------
# Annoy index     : 231
# Image file name : AVpgptyp1cnluZ0-4hXT
# Product id      : AVpgptyp1cnluZ0-4hXT
# AVpgqbpQ1cnluZ0-4rVL
# ---------------------------------
# Annoy index     : 232
# Image file name : AVpgqbpQ1cnluZ0-4rVL
# Product id      : AVpgqbpQ1cnluZ0-4rVL
# AVpgqDb-LJeJML43RCBy
# ---------------------------------
# Annoy index     : 233
# Image file name : AVpgqDb-LJeJML43RCBy
# Product id      : AVpgqDb-LJeJML43RCBy
# AVpgRU8zLJeJML43Lhfa
# ---------------------------------
# Annoy index     : 234
# Image file name : AVpgRU8zLJeJML43Lhfa
# Product id      : AVpgRU8zLJeJML43Lhfa
# AVpgsqiDLJeJML43Rnqo
# ---------------------------------
# Annoy index     : 235
# Image file name : AVpgsqiDLJeJML43Rnqo
# Product id      : AVpgsqiDLJeJML43Rnqo
# AVpgt0zRLJeJML43R4Ln
# ---------------------------------
# Annoy index     : 236
# Image file name : AVpgt0zRLJeJML43R4Ln
# Product id      : AVpgt0zRLJeJML43R4Ln
# AVpgtbPc1cnluZ0-5Wqx
# ---------------------------------
# Annoy index     : 237
# Image file name : AVpgtbPc1cnluZ0-5Wqx
# Product id      : AVpgtbPc1cnluZ0-5Wqx
# AVpgueGELJeJML43SAvc
# ---------------------------------
# Annoy index     : 238
# Image file name : AVpgueGELJeJML43SAvc
# Product id      : AVpgueGELJeJML43SAvc
# AVpguk8cLJeJML43SCTT
# ---------------------------------
# Annoy index     : 239
# Image file name : AVpguk8cLJeJML43SCTT
# Product id      : AVpguk8cLJeJML43SCTT
# AVpgvcbv1cnluZ0-5x_E
# ---------------------------------
# Annoy index     : 240
# Image file name : AVpgvcbv1cnluZ0-5x_E
# Product id      : AVpgvcbv1cnluZ0-5x_E
# AVpgvLoL1cnluZ0-5unJ
# ---------------------------------
# Annoy index     : 241
# Image file name : AVpgvLoL1cnluZ0-5unJ
# Product id      : AVpgvLoL1cnluZ0-5unJ
# AVpgy3AgilAPnD_xxYle
# ---------------------------------
# Annoy index     : 242
# Image file name : AVpgy3AgilAPnD_xxYle
# Product id      : AVpgy3AgilAPnD_xxYle
# AVpgzk2v1cnluZ0-6jnn
# ---------------------------------
# Annoy index     : 243
# Image file name : AVpgzk2v1cnluZ0-6jnn
# Product id      : AVpgzk2v1cnluZ0-6jnn
# AVpgZUfE1cnluZ0-05Om
# ---------------------------------
# Annoy index     : 244
# Image file name : AVpgZUfE1cnluZ0-05Om
# Product id      : AVpgZUfE1cnluZ0-05Om
# AVph1d5VilAPnD_x926A
# ---------------------------------
# Annoy index     : 245
# Image file name : AVph1d5VilAPnD_x926A
# Product id      : AVph1d5VilAPnD_x926A
# AVph2NUtilAPnD_x9_W_
# ---------------------------------
# Annoy index     : 246
# Image file name : AVph2NUtilAPnD_x9_W_
# Product id      : AVph2NUtilAPnD_x9_W_
# AVph34uzilAPnD_x-STz
# ---------------------------------
# Annoy index     : 247
# Image file name : AVph34uzilAPnD_x-STz
# Product id      : AVph34uzilAPnD_x-STz
# AVph3mXu1cnluZ0-HT3k
# ---------------------------------
# Annoy index     : 248
# Image file name : AVph3mXu1cnluZ0-HT3k
# Product id      : AVph3mXu1cnluZ0-HT3k
# AVph4acGLJeJML43f4tN
# ---------------------------------
# Annoy index     : 249
# Image file name : AVph4acGLJeJML43f4tN
# Product id      : AVph4acGLJeJML43f4tN
# AVph5yRIilAPnD_x-nZ8
# ---------------------------------
# Annoy index     : 250
# Image file name : AVph5yRIilAPnD_x-nZ8
# Product id      : AVph5yRIilAPnD_x-nZ8
# AVph9abqilAPnD_x_Nrp
# ---------------------------------
# Annoy index     : 251
# Image file name : AVph9abqilAPnD_x_Nrp
# Product id      : AVph9abqilAPnD_x_Nrp
# AVph9cx8ilAPnD_x_OCE
# ---------------------------------
# Annoy index     : 252
# Image file name : AVph9cx8ilAPnD_x_OCE
# Product id      : AVph9cx8ilAPnD_x_OCE
# AVphAoQfilAPnD_x0GYd
# ---------------------------------
# Annoy index     : 253
# Image file name : AVphAoQfilAPnD_x0GYd
# Product id      : AVphAoQfilAPnD_x0GYd
# AVphbej3LJeJML43azqf
# ---------------------------------
# Annoy index     : 254
# Image file name : AVphbej3LJeJML43azqf
# Product id      : AVphbej3LJeJML43azqf
# AVphbNXp1cnluZ0-CU4j
# ---------------------------------
# Annoy index     : 255
# Image file name : AVphbNXp1cnluZ0-CU4j
# Product id      : AVphbNXp1cnluZ0-CU4j
# AVphd3eULJeJML43bQDG
# ---------------------------------
# Annoy index     : 256
# Image file name : AVphd3eULJeJML43bQDG
# Product id      : AVphd3eULJeJML43bQDG
# AVphdM2LilAPnD_x5oWU
# ---------------------------------
# Annoy index     : 257
# Image file name : AVphdM2LilAPnD_x5oWU
# Product id      : AVphdM2LilAPnD_x5oWU
# AVphEgjtLJeJML43WXSG
# ---------------------------------
# Annoy index     : 258
# Image file name : AVphEgjtLJeJML43WXSG
# Product id      : AVphEgjtLJeJML43WXSG
# AVphf6M51cnluZ0-DNIG
# ---------------------------------
# Annoy index     : 259
# Image file name : AVphf6M51cnluZ0-DNIG
# Product id      : AVphf6M51cnluZ0-DNIG
# AVphFVCgilAPnD_x1Cnp
# ---------------------------------
# Annoy index     : 260
# Image file name : AVphFVCgilAPnD_x1Cnp
# Product id      : AVphFVCgilAPnD_x1Cnp
# AVphfynfilAPnD_x6HNA
# ---------------------------------
# Annoy index     : 261
# Image file name : AVphfynfilAPnD_x6HNA
# Product id      : AVphfynfilAPnD_x6HNA
# AVphgfltilAPnD_x6PXj
# ---------------------------------
# Annoy index     : 262
# Image file name : AVphgfltilAPnD_x6PXj
# Product id      : AVphgfltilAPnD_x6PXj
# AVphGjZN1cnluZ0--WSL
# ---------------------------------
# Annoy index     : 263
# Image file name : AVphGjZN1cnluZ0--WSL
# Product id      : AVphGjZN1cnluZ0--WSL
# AVphGKLPilAPnD_x1Nrm
# ---------------------------------
# Annoy index     : 264
# Image file name : AVphGKLPilAPnD_x1Nrm
# Product id      : AVphGKLPilAPnD_x1Nrm
# AVphh4Hf1cnluZ0-Djws
# ---------------------------------
# Annoy index     : 265
# Image file name : AVphh4Hf1cnluZ0-Djws
# Product id      : AVphh4Hf1cnluZ0-Djws
# AVphhlhmilAPnD_x6cM-
# ---------------------------------
# Annoy index     : 266
# Image file name : AVphhlhmilAPnD_x6cM-
# Product id      : AVphhlhmilAPnD_x6cM-
# AVphhwCE1cnluZ0-DiSZ
# ---------------------------------
# Annoy index     : 267
# Image file name : AVphhwCE1cnluZ0-DiSZ
# Product id      : AVphhwCE1cnluZ0-DiSZ
# AVphIXayilAPnD_x1qtc
# ---------------------------------
# Annoy index     : 268
# Image file name : AVphIXayilAPnD_x1qtc
# Product id      : AVphIXayilAPnD_x1qtc
# AVphK52oLJeJML43XpfU
# ---------------------------------
# Annoy index     : 269
# Image file name : AVphK52oLJeJML43XpfU
# Product id      : AVphK52oLJeJML43XpfU
# AVphKpMgilAPnD_x2HEj
# ---------------------------------
# Annoy index     : 270
# Image file name : AVphKpMgilAPnD_x2HEj
# Product id      : AVphKpMgilAPnD_x2HEj
# AVphl0I-ilAPnD_x7JVw
# ---------------------------------
# Annoy index     : 271
# Image file name : AVphl0I-ilAPnD_x7JVw
# Product id      : AVphl0I-ilAPnD_x7JVw
# AVphm6G5LJeJML43c0Je
# ---------------------------------
# Annoy index     : 272
# Image file name : AVphm6G5LJeJML43c0Je
# Product id      : AVphm6G5LJeJML43c0Je
# AVphmNGP1cnluZ0-ERus
# ---------------------------------
# Annoy index     : 273
# Image file name : AVphmNGP1cnluZ0-ERus
# Product id      : AVphmNGP1cnluZ0-ERus
# AVphMYu61cnluZ0-_gDM
# ---------------------------------
# Annoy index     : 274
# Image file name : AVphMYu61cnluZ0-_gDM
# Product id      : AVphMYu61cnluZ0-_gDM
# AVphMzNsilAPnD_x2h9H
# ---------------------------------
# Annoy index     : 275
# Image file name : AVphMzNsilAPnD_x2h9H
# Product id      : AVphMzNsilAPnD_x2h9H
# AVphNCCqilAPnD_x2k7_
# ---------------------------------
# Annoy index     : 276
# Image file name : AVphNCCqilAPnD_x2k7_
# Product id      : AVphNCCqilAPnD_x2k7_
# AVphq-E9ilAPnD_x8Bgo
# ---------------------------------
# Annoy index     : 277
# Image file name : AVphq-E9ilAPnD_x8Bgo
# Product id      : AVphq-E9ilAPnD_x8Bgo
# AVphq8Ny1cnluZ0-FFnv
# ---------------------------------
# Annoy index     : 278
# Image file name : AVphq8Ny1cnluZ0-FFnv
# Product id      : AVphq8Ny1cnluZ0-FFnv
# AVphQAiiilAPnD_x3J-8
# ---------------------------------
# Annoy index     : 279
# Image file name : AVphQAiiilAPnD_x3J-8
# Product id      : AVphQAiiilAPnD_x3J-8
# AVphQm0-ilAPnD_x3RCO
# ---------------------------------
# Annoy index     : 280
# Image file name : AVphQm0-ilAPnD_x3RCO
# Product id      : AVphQm0-ilAPnD_x3RCO
# AVphqVhoLJeJML43dZ2a
# ---------------------------------
# Annoy index     : 281
# Image file name : AVphqVhoLJeJML43dZ2a
# Product id      : AVphqVhoLJeJML43dZ2a
# AVphuQmk1cnluZ0-FqyR
# ---------------------------------
# Annoy index     : 282
# Image file name : AVphuQmk1cnluZ0-FqyR
# Product id      : AVphuQmk1cnluZ0-FqyR
# AVphvRvnLJeJML43eRsr
# ---------------------------------
# Annoy index     : 283
# Image file name : AVphvRvnLJeJML43eRsr
# Product id      : AVphvRvnLJeJML43eRsr
# AVphX0ZbLJeJML43aHNG
# ---------------------------------
# Annoy index     : 284
# Image file name : AVphX0ZbLJeJML43aHNG
# Product id      : AVphX0ZbLJeJML43aHNG
# AVphXIhELJeJML43Z-74
# ---------------------------------
# Annoy index     : 285
# Image file name : AVphXIhELJeJML43Z-74
# Product id      : AVphXIhELJeJML43Z-74
# AVphXJJsilAPnD_x4fw2
# ---------------------------------
# Annoy index     : 286
# Image file name : AVphXJJsilAPnD_x4fw2
# Product id      : AVphXJJsilAPnD_x4fw2
# AVphyHO1ilAPnD_x9RjY
# ---------------------------------
# Annoy index     : 287
# Image file name : AVphyHO1ilAPnD_x9RjY
# Product id      : AVphyHO1ilAPnD_x9RjY
# AVphYvWT1cnluZ0-B2_L
# ---------------------------------
# Annoy index     : 288
# Image file name : AVphYvWT1cnluZ0-B2_L
# Product id      : AVphYvWT1cnluZ0-B2_L
# AVphyzaZLJeJML43e5WQ
# ---------------------------------
# Annoy index     : 289
# Image file name : AVphyzaZLJeJML43e5WQ
# Product id      : AVphyzaZLJeJML43e5WQ
# AVphZ_Xk1cnluZ0-CF5V
# ---------------------------------
# Annoy index     : 290
# Image file name : AVphZ_Xk1cnluZ0-CF5V
# Product id      : AVphZ_Xk1cnluZ0-CF5V
# AVph_sRxilAPnD_x_kaA
# ---------------------------------
# Annoy index     : 291
# Image file name : AVph_sRxilAPnD_x_kaA
# Product id      : AVph_sRxilAPnD_x_kaA
# AVpi-ZoW1cnluZ0-SXMx
# ---------------------------------
# Annoy index     : 292
# Image file name : AVpi-ZoW1cnluZ0-SXMx
# Product id      : AVpi-ZoW1cnluZ0-SXMx
# AVpi1y6tilAPnD_xIAXa
# ---------------------------------
# Annoy index     : 293
# Image file name : AVpi1y6tilAPnD_xIAXa
# Product id      : AVpi1y6tilAPnD_xIAXa
# AVpi2jgTLJeJML43pot5
# ---------------------------------
# Annoy index     : 294
# Image file name : AVpi2jgTLJeJML43pot5
# Product id      : AVpi2jgTLJeJML43pot5
# AVpi2XjjilAPnD_xIFTL
# ---------------------------------
# Annoy index     : 295
# Image file name : AVpi2XjjilAPnD_xIFTL
# Product id      : AVpi2XjjilAPnD_xIFTL
# AVpi5EzrLJeJML43p-O3
# ---------------------------------
# Annoy index     : 296
# Image file name : AVpi5EzrLJeJML43p-O3
# Product id      : AVpi5EzrLJeJML43p-O3
# AVpi74XfLJeJML43qZAc
# ---------------------------------
# Annoy index     : 297
# Image file name : AVpi74XfLJeJML43qZAc
# Product id      : AVpi74XfLJeJML43qZAc
# AVpi9CQ0LJeJML43qkte
# ---------------------------------
# Annoy index     : 298
# Image file name : AVpi9CQ0LJeJML43qkte
# Product id      : AVpi9CQ0LJeJML43qkte
# AVpia2K6LJeJML43lhA-
# ---------------------------------
# Annoy index     : 299
# Image file name : AVpia2K6LJeJML43lhA-
# Product id      : AVpia2K6LJeJML43lhA-
# AVpiATp9ilAPnD_x_qyh
# ---------------------------------
# Annoy index     : 300
# Image file name : AVpiATp9ilAPnD_x_qyh
# Product id      : AVpiATp9ilAPnD_x_qyh
# AVpidVDz1cnluZ0-Nd4_
# ---------------------------------
# Annoy index     : 301
# Image file name : AVpidVDz1cnluZ0-Nd4_
# Product id      : AVpidVDz1cnluZ0-Nd4_
# AVpieLSVLJeJML43mATo
# ---------------------------------
# Annoy index     : 302
# Image file name : AVpieLSVLJeJML43mATo
# Product id      : AVpieLSVLJeJML43mATo
# AVpiewWrilAPnD_xEkjw
# ---------------------------------
# Annoy index     : 303
# Image file name : AVpiewWrilAPnD_xEkjw
# Product id      : AVpiewWrilAPnD_xEkjw
# AVpiF4-31cnluZ0-Jvov
# ---------------------------------
# Annoy index     : 304
# Image file name : AVpiF4-31cnluZ0-Jvov
# Product id      : AVpiF4-31cnluZ0-Jvov
# AVpighYz1cnluZ0-N8EB
# ---------------------------------
# Annoy index     : 305
# Image file name : AVpighYz1cnluZ0-N8EB
# Product id      : AVpighYz1cnluZ0-N8EB
# AVpiJ0A4LJeJML43i1zi
# ---------------------------------
# Annoy index     : 306
# Image file name : AVpiJ0A4LJeJML43i1zi
# Product id      : AVpiJ0A4LJeJML43i1zi
# AVpiJn-v1cnluZ0-KZEJ
# ---------------------------------
# Annoy index     : 307
# Image file name : AVpiJn-v1cnluZ0-KZEJ
# Product id      : AVpiJn-v1cnluZ0-KZEJ
# AVpijweFLJeJML43m1Hf
# ---------------------------------
# Annoy index     : 308
# Image file name : AVpijweFLJeJML43m1Hf
# Product id      : AVpijweFLJeJML43m1Hf
# AVpij_dBilAPnD_xFV8S
# ---------------------------------
# Annoy index     : 309
# Image file name : AVpij_dBilAPnD_xFV8S
# Product id      : AVpij_dBilAPnD_xFV8S
# ...
# Image file name : AWo0hSQnJbEilcB6MTL5
# Product id      : AWo0hSQnJbEilcB6MTL5
# AWo0hT9MJbEilcB6MTMi
# ---------------------------------
# Annoy index     : 672
# Image file name : AWo0hT9MJbEilcB6MTMi
# Product id      : AWo0hT9MJbEilcB6MTMi
# AWo0ht_R0U_gzG0hez2N
# ---------------------------------
# Annoy index     : 673
# Image file name : AWo0ht_R0U_gzG0hez2N
# Product id      : AWo0ht_R0U_gzG0hez2N
# AWo0hUKz0U_gzG0hezo7
# ---------------------------------
# Annoy index     : 674
# Image file name : AWo0hUKz0U_gzG0hezo7
# Product id      : AWo0hUKz0U_gzG0hezo7
# AWo0hvKcJbEilcB6MTaM
# ---------------------------------
# Annoy index     : 675
# Image file name : AWo0hvKcJbEilcB6MTaM
# Product id      : AWo0hvKcJbEilcB6MTaM
# AWo0hVkgJbEilcB6MTNS
# ---------------------------------
# Annoy index     : 676
# Image file name : AWo0hVkgJbEilcB6MTNS
# Product id      : AWo0hVkgJbEilcB6MTNS
# AWo0hWSWM263mwCq50Tf
# ---------------------------------
# Annoy index     : 677
# Image file name : AWo0hWSWM263mwCq50Tf
# Product id      : AWo0hWSWM263mwCq50Tf
# AWo0hWV-JbEilcB6MTNr
# ---------------------------------
# Annoy index     : 678
# Image file name : AWo0hWV-JbEilcB6MTNr
# Product id      : AWo0hWV-JbEilcB6MTNr
# AWo0hxNyM263mwCq50hM
# ---------------------------------
# Annoy index     : 679
# Image file name : AWo0hxNyM263mwCq50hM
# Product id      : AWo0hxNyM263mwCq50hM
# AWo0hXtn0U_gzG0hezqh
# ---------------------------------
# Annoy index     : 680
# Image file name : AWo0hXtn0U_gzG0hezqh
# Product id      : AWo0hXtn0U_gzG0hezqh
# AWo0hYAUM263mwCq50UG
# ---------------------------------
# Annoy index     : 681
# Image file name : AWo0hYAUM263mwCq50UG
# Product id      : AWo0hYAUM263mwCq50UG
# AWo0hYceM263mwCq50UW
# ---------------------------------
# Annoy index     : 682
# Image file name : AWo0hYceM263mwCq50UW
# Product id      : AWo0hYceM263mwCq50UW
# AWo0hYRIJbEilcB6MTOv
# ---------------------------------
# Annoy index     : 683
# Image file name : AWo0hYRIJbEilcB6MTOv
# Product id      : AWo0hYRIJbEilcB6MTOv
# AWo0hYWC0U_gzG0hezq2
# ---------------------------------
# Annoy index     : 684
# Image file name : AWo0hYWC0U_gzG0hezq2
# Product id      : AWo0hYWC0U_gzG0hezq2
# AWo0ia73M263mwCq500F
# ---------------------------------
# Annoy index     : 685
# Image file name : AWo0ia73M263mwCq500F
# Product id      : AWo0ia73M263mwCq500F
# AWo0iAlQ0U_gzG0hez-A
# ---------------------------------
# Annoy index     : 686
# Image file name : AWo0iAlQ0U_gzG0hez-A
# Product id      : AWo0iAlQ0U_gzG0hez-A
# AWo0iBTnJbEilcB6MTi1
# ---------------------------------
# Annoy index     : 687
# Image file name : AWo0iBTnJbEilcB6MTi1
# Product id      : AWo0iBTnJbEilcB6MTi1
# AWo0iC2P0U_gzG0hez_H
# ---------------------------------
# Annoy index     : 688
# Image file name : AWo0iC2P0U_gzG0hez_H
# Product id      : AWo0iC2P0U_gzG0hez_H
# AWo0iCVFJbEilcB6MTjT
# ---------------------------------
# Annoy index     : 689
# Image file name : AWo0iCVFJbEilcB6MTjT
# Product id      : AWo0iCVFJbEilcB6MTjT
# AWo0idFOJbEilcB6MTwb
# ---------------------------------
# Annoy index     : 690
# Image file name : AWo0idFOJbEilcB6MTwb
# Product id      : AWo0idFOJbEilcB6MTwb
# AWo0idiA0U_gzG0he0LA
# ---------------------------------
# Annoy index     : 691
# Image file name : AWo0idiA0U_gzG0he0LA
# Product id      : AWo0idiA0U_gzG0he0LA
# AWo0iEF8JbEilcB6MTkI
# ---------------------------------
# Annoy index     : 692
# Image file name : AWo0iEF8JbEilcB6MTkI
# Product id      : AWo0iEF8JbEilcB6MTkI
# AWo0ieNqM263mwCq502m
# ---------------------------------
# Annoy index     : 693
# Image file name : AWo0ieNqM263mwCq502m
# Product id      : AWo0ieNqM263mwCq502m
# AWo0iEx8AGTnQPR7rA-n
# ---------------------------------
# Annoy index     : 694
# Image file name : AWo0iEx8AGTnQPR7rA-n
# Product id      : AWo0iEx8AGTnQPR7rA-n
# AWo0igqPAGTnQPR7rBN7
# ---------------------------------
# Annoy index     : 695
# Image file name : AWo0igqPAGTnQPR7rBN7
# Product id      : AWo0igqPAGTnQPR7rBN7
# AWo0iHGW0U_gzG0he0A_
# ---------------------------------
# Annoy index     : 696
# Image file name : AWo0iHGW0U_gzG0he0A_
# Product id      : AWo0iHGW0U_gzG0he0A_
# AWo0iiv_M263mwCq505i
# ---------------------------------
# Annoy index     : 697
# Image file name : AWo0iiv_M263mwCq505i
# Product id      : AWo0iiv_M263mwCq505i
# AWo0iiyQAGTnQPR7rBPU
# ---------------------------------
# Annoy index     : 698
# Image file name : AWo0iiyQAGTnQPR7rBPU
# Product id      : AWo0iiyQAGTnQPR7rBPU
# AWo0iJGdM263mwCq50rA
# ---------------------------------
# Annoy index     : 699
# Image file name : AWo0iJGdM263mwCq50rA
# Product id      : AWo0iJGdM263mwCq50rA
# AWo0ijKWJbEilcB6MT0f
# ---------------------------------
# Annoy index     : 700
# Image file name : AWo0ijKWJbEilcB6MT0f
# Product id      : AWo0ijKWJbEilcB6MT0f
# AWo0iJPX0U_gzG0he0BX
# ---------------------------------
# Annoy index     : 701
# Image file name : AWo0iJPX0U_gzG0he0BX
# Product id      : AWo0iJPX0U_gzG0he0BX
# AWo0ikN-AGTnQPR7rBQJ
# ---------------------------------
# Annoy index     : 702
# Image file name : AWo0ikN-AGTnQPR7rBQJ
# Product id      : AWo0ikN-AGTnQPR7rBQJ
# AWo0ikSvAGTnQPR7rBQL
# ---------------------------------
# Annoy index     : 703
# Image file name : AWo0ikSvAGTnQPR7rBQL
# Product id      : AWo0ikSvAGTnQPR7rBQL
# AWo0iKv6JbEilcB6MTmb
# ---------------------------------
# Annoy index     : 704
# Image file name : AWo0iKv6JbEilcB6MTmb
# Product id      : AWo0iKv6JbEilcB6MTmb
# AWo0il6P0U_gzG0he0QF
# ---------------------------------
# Annoy index     : 705
# Image file name : AWo0il6P0U_gzG0he0QF
# Product id      : AWo0il6P0U_gzG0he0QF
# AWo0ilHe0U_gzG0he0Pn
# ---------------------------------
# Annoy index     : 706
# Image file name : AWo0ilHe0U_gzG0he0Pn
# Product id      : AWo0ilHe0U_gzG0he0Pn
# AWo0iTWTJbEilcB6MTqT
# ---------------------------------
# Annoy index     : 707
# Image file name : AWo0iTWTJbEilcB6MTqT
# Product id      : AWo0iTWTJbEilcB6MTqT
# AWo0iT_40U_gzG0he0Fo
# ---------------------------------
# Annoy index     : 708
# Image file name : AWo0iT_40U_gzG0he0Fo
# Product id      : AWo0iT_40U_gzG0he0Fo
# AWo0iZgBM263mwCq50zU
# ---------------------------------
# Annoy index     : 709
# Image file name : AWo0iZgBM263mwCq50zU
# Product id      : AWo0iZgBM263mwCq50zU
# AWo0iZgeAGTnQPR7rBIR
# ---------------------------------
# Annoy index     : 710
# Image file name : AWo0iZgeAGTnQPR7rBIR
# Product id      : AWo0iZgeAGTnQPR7rBIR
# AWo0jcmtM263mwCq51Bo
# ---------------------------------
# Annoy index     : 711
# Image file name : AWo0jcmtM263mwCq51Bo
# Product id      : AWo0jcmtM263mwCq51Bo
# AWo0jjmBM263mwCq51DB
# ---------------------------------
# Annoy index     : 712
# Image file name : AWo0jjmBM263mwCq51DB
# Product id      : AWo0jjmBM263mwCq51DB
# AWo0jjT6M263mwCq51C7
# ---------------------------------
# Annoy index     : 713
# Image file name : AWo0jjT6M263mwCq51C7
# Product id      : AWo0jjT6M263mwCq51C7
# AWo0jmVDJbEilcB6MT9n
# ---------------------------------
# Annoy index     : 714
# Image file name : AWo0jmVDJbEilcB6MT9n
# Product id      : AWo0jmVDJbEilcB6MT9n
# AWo0jy6aM263mwCq51E1
# ---------------------------------
# Annoy index     : 715
# Image file name : AWo0jy6aM263mwCq51E1
# Product id      : AWo0jy6aM263mwCq51E1
# AWo0k2knAGTnQPR7rBiq
# ---------------------------------
# Annoy index     : 716
# Image file name : AWo0k2knAGTnQPR7rBiq
# Product id      : AWo0k2knAGTnQPR7rBiq
# AWo0k5UyJbEilcB6MUIN
# ---------------------------------
# Annoy index     : 717
# Image file name : AWo0k5UyJbEilcB6MUIN
# Product id      : AWo0k5UyJbEilcB6MUIN
# AWo0kC2tM263mwCq51Hh
# ---------------------------------
# Annoy index     : 718
# Image file name : AWo0kC2tM263mwCq51Hh
# Product id      : AWo0kC2tM263mwCq51Hh
# AWo0kF1aM263mwCq51ID
# ---------------------------------
# Annoy index     : 719
# Image file name : AWo0kF1aM263mwCq51ID
# Product id      : AWo0kF1aM263mwCq51ID
# AWo0kfGxM263mwCq51LO
# ---------------------------------
# Annoy index     : 720
# Image file name : AWo0kfGxM263mwCq51LO
# Product id      : AWo0kfGxM263mwCq51LO
# AWo0kLeH0U_gzG0he0c9
# ---------------------------------
# Annoy index     : 721
# Image file name : AWo0kLeH0U_gzG0he0c9
# Product id      : AWo0kLeH0U_gzG0he0c9
# AWo0kRdoAGTnQPR7rBe_
# ---------------------------------
# Annoy index     : 722
# Image file name : AWo0kRdoAGTnQPR7rBe_
# Product id      : AWo0kRdoAGTnQPR7rBe_
# AWo0kUnLM263mwCq51KY
# ---------------------------------
# Annoy index     : 723
# Image file name : AWo0kUnLM263mwCq51KY
# Product id      : AWo0kUnLM263mwCq51KY
# AWo0kURoJbEilcB6MUEm
# ---------------------------------
# Annoy index     : 724
# Image file name : AWo0kURoJbEilcB6MUEm
# Product id      : AWo0kURoJbEilcB6MUEm
# AWo0kw910U_gzG0he0hC
# ---------------------------------
# Annoy index     : 725
# Image file name : AWo0kw910U_gzG0he0hC
# Product id      : AWo0kw910U_gzG0he0hC
# AWo0l0SPAGTnQPR7rBq-
# ---------------------------------
# Annoy index     : 726
# Image file name : AWo0l0SPAGTnQPR7rBq-
# Product id      : AWo0l0SPAGTnQPR7rBq-
# AWo0lfjR0U_gzG0he0m1
# ---------------------------------
# Annoy index     : 727
# Image file name : AWo0lfjR0U_gzG0he0m1
# Product id      : AWo0lfjR0U_gzG0he0m1
# AWo0llPQJbEilcB6MUOS
# ---------------------------------
# Annoy index     : 728
# Image file name : AWo0llPQJbEilcB6MUOS
# Product id      : AWo0llPQJbEilcB6MUOS
# AWo0ltA4AGTnQPR7rBp-
# ---------------------------------
# Annoy index     : 729
# Image file name : AWo0ltA4AGTnQPR7rBp-
# Product id      : AWo0ltA4AGTnQPR7rBp-
# AWo0ltQB0U_gzG0he0pC
# ---------------------------------
# Annoy index     : 730
# Image file name : AWo0ltQB0U_gzG0he0pC
# Product id      : AWo0ltQB0U_gzG0he0pC
# AWo0lXBTM263mwCq51Re
# ---------------------------------
# Annoy index     : 731
# Image file name : AWo0lXBTM263mwCq51Re
# Product id      : AWo0lXBTM263mwCq51Re
# AWo0lXLzM263mwCq51Rj
# ---------------------------------
# Annoy index     : 732
# Image file name : AWo0lXLzM263mwCq51Rj
# Product id      : AWo0lXLzM263mwCq51Rj
# AWo0lXQ30U_gzG0he0lu
# ---------------------------------
# Annoy index     : 733
# Image file name : AWo0lXQ30U_gzG0he0lu
# Product id      : AWo0lXQ30U_gzG0he0lu
# AWo0m22GAGTnQPR7rBz7
# ---------------------------------
# Annoy index     : 734
# Image file name : AWo0m22GAGTnQPR7rBz7
# Product id      : AWo0m22GAGTnQPR7rBz7
# AWo0m24OJbEilcB6MUZO
# ---------------------------------
# Annoy index     : 735
# Image file name : AWo0m24OJbEilcB6MUZO
# Product id      : AWo0m24OJbEilcB6MUZO
# AWo0m2qMAGTnQPR7rBz0
# ---------------------------------
# Annoy index     : 736
# Image file name : AWo0m2qMAGTnQPR7rBz0
# Product id      : AWo0m2qMAGTnQPR7rBz0
# AWo0mhdH0U_gzG0he0vq
# ---------------------------------
# Annoy index     : 737
# Image file name : AWo0mhdH0U_gzG0he0vq
# Product id      : AWo0mhdH0U_gzG0he0vq
# AWo0mknt0U_gzG0he0wP
# ---------------------------------
# Annoy index     : 738
# Image file name : AWo0mknt0U_gzG0he0wP
# Product id      : AWo0mknt0U_gzG0he0wP
# AWo0mQEhM263mwCq51X4
# ---------------------------------
# Annoy index     : 739
# Image file name : AWo0mQEhM263mwCq51X4
# Product id      : AWo0mQEhM263mwCq51X4
# AWo0mQV-M263mwCq51YA
# ---------------------------------
# Annoy index     : 740
# Image file name : AWo0mQV-M263mwCq51YA
# Product id      : AWo0mQV-M263mwCq51YA
# AWo0mv6FAGTnQPR7rBzB
# ---------------------------------
# Annoy index     : 741
# Image file name : AWo0mv6FAGTnQPR7rBzB
# Product id      : AWo0mv6FAGTnQPR7rBzB
# AWo0nACN0U_gzG0he0zJ
# ---------------------------------
# Annoy index     : 742
# Image file name : AWo0nACN0U_gzG0he0zJ
# Product id      : AWo0nACN0U_gzG0he0zJ
# AWo0Qn8_AGTnQPR7q6w5
# ---------------------------------
# Annoy index     : 743
# Image file name : AWo0Qn8_AGTnQPR7q6w5
# Product id      : AWo0Qn8_AGTnQPR7q6w5
# AWo0Qn_AAGTnQPR7q6w8
# ---------------------------------
# Annoy index     : 744
# Image file name : AWo0Qn_AAGTnQPR7q6w8
# Product id      : AWo0Qn_AAGTnQPR7q6w8
# AWo0QxQW0U_gzG0het3m
# ---------------------------------
# Annoy index     : 745
# Image file name : AWo0QxQW0U_gzG0het3m
# Product id      : AWo0QxQW0U_gzG0het3m
# AWo0QzhvM263mwCq5ui9
# ---------------------------------
# Annoy index     : 746
# Image file name : AWo0QzhvM263mwCq5ui9
# Product id      : AWo0QzhvM263mwCq5ui9
# AWo0Q_b6JbEilcB6MNrx
# ---------------------------------
# Annoy index     : 747
# Image file name : AWo0Q_b6JbEilcB6MNrx
# Product id      : AWo0Q_b6JbEilcB6MNrx
# AWo0REGDJbEilcB6MNxj
# ---------------------------------
# Annoy index     : 748
# Image file name : AWo0REGDJbEilcB6MNxj
# Product id      : AWo0REGDJbEilcB6MNxj
# AWo0RJfIM263mwCq5u8c
# ---------------------------------
# Annoy index     : 749
# Image file name : AWo0RJfIM263mwCq5u8c
# Product id      : AWo0RJfIM263mwCq5u8c
# AWo0RneMAGTnQPR7q7qp
# ---------------------------------
# Annoy index     : 750
# Image file name : AWo0RneMAGTnQPR7q7qp
# Product id      : AWo0RneMAGTnQPR7q7qp
# AWo0RRTCM263mwCq5vFC
# ---------------------------------
# Annoy index     : 751
# Image file name : AWo0RRTCM263mwCq5vFC
# Product id      : AWo0RRTCM263mwCq5vFC
# AWo0R_9LJbEilcB6MOVq
# ---------------------------------
# Annoy index     : 752
# Image file name : AWo0R_9LJbEilcB6MOVq
# Product id      : AWo0R_9LJbEilcB6MOVq
# AWo0S8NzJbEilcB6MOwO
# ---------------------------------
# Annoy index     : 753
# Image file name : AWo0S8NzJbEilcB6MOwO
# Product id      : AWo0S8NzJbEilcB6MOwO
# AWo0SMVrM263mwCq5veL
# ---------------------------------
# Annoy index     : 754
# Image file name : AWo0SMVrM263mwCq5veL
# Product id      : AWo0SMVrM263mwCq5veL
# AWo0SQ3FM263mwCq5vgD
# ---------------------------------
# Annoy index     : 755
# Image file name : AWo0SQ3FM263mwCq5vgD
# Product id      : AWo0SQ3FM263mwCq5vgD
# AWo0SR-pJbEilcB6MOdH
# ---------------------------------
# Annoy index     : 756
# Image file name : AWo0SR-pJbEilcB6MOdH
# Product id      : AWo0SR-pJbEilcB6MOdH
# AWo0SvfT0U_gzG0hevDs
# ---------------------------------
# Annoy index     : 757
# Image file name : AWo0SvfT0U_gzG0hevDs
# Product id      : AWo0SvfT0U_gzG0hevDs
# AWo0t0CTAGTnQPR7rCEj
# ---------------------------------
# Annoy index     : 758
# Image file name : AWo0t0CTAGTnQPR7rCEj
# Product id      : AWo0t0CTAGTnQPR7rCEj
# AWo0T15rJbEilcB6MPMH
# ---------------------------------
# Annoy index     : 759
# Image file name : AWo0T15rJbEilcB6MPMH
# Product id      : AWo0T15rJbEilcB6MPMH
# AWo0TELT0U_gzG0hevOW
# ---------------------------------
# Annoy index     : 760
# Image file name : AWo0TELT0U_gzG0hevOW
# Product id      : AWo0TELT0U_gzG0hevOW
# AWo0Te_FAGTnQPR7q8el
# ---------------------------------
# Annoy index     : 761
# Image file name : AWo0Te_FAGTnQPR7q8el
# Product id      : AWo0Te_FAGTnQPR7q8el
# AWo0TGMUM263mwCq5v4F
# ---------------------------------
# Annoy index     : 762
# Image file name : AWo0TGMUM263mwCq5v4F
# Product id      : AWo0TGMUM263mwCq5v4F
# AWo0TI_vM263mwCq5v5y
# ---------------------------------
# Annoy index     : 763
# Image file name : AWo0TI_vM263mwCq5v5y
# Product id      : AWo0TI_vM263mwCq5v5y
# AWo0TmVJAGTnQPR7q8iU
# ---------------------------------
# Annoy index     : 764
# Image file name : AWo0TmVJAGTnQPR7q8iU
# Product id      : AWo0TmVJAGTnQPR7q8iU
# AWo0TNAbM263mwCq5v7v
# ---------------------------------
# Annoy index     : 765
# Image file name : AWo0TNAbM263mwCq5v7v
# Product id      : AWo0TNAbM263mwCq5v7v
# AWo0TNdwM263mwCq5v77
# ---------------------------------
# Annoy index     : 766
# Image file name : AWo0TNdwM263mwCq5v77
# Product id      : AWo0TNdwM263mwCq5v77
# AWo0TnYuAGTnQPR7q8iq
# ---------------------------------
# Annoy index     : 767
# Image file name : AWo0TnYuAGTnQPR7q8iq
# Product id      : AWo0TnYuAGTnQPR7q8iq
# AWo0Tp8DAGTnQPR7q8kB
# ---------------------------------
# Annoy index     : 768
# Image file name : AWo0Tp8DAGTnQPR7q8kB
# Product id      : AWo0Tp8DAGTnQPR7q8kB
# AWo0Tq91AGTnQPR7q8km
# ---------------------------------
# Annoy index     : 769
# Image file name : AWo0Tq91AGTnQPR7q8km
# Product id      : AWo0Tq91AGTnQPR7q8km
# AWo0U2qqJbEilcB6MPuF
# ---------------------------------
# Annoy index     : 770
# Image file name : AWo0U2qqJbEilcB6MPuF
# Product id      : AWo0U2qqJbEilcB6MPuF
# AWo0UAODAGTnQPR7q8u1
# ---------------------------------
# Annoy index     : 771
# Image file name : AWo0UAODAGTnQPR7q8u1
# Product id      : AWo0UAODAGTnQPR7q8u1
# AWo0UGybJbEilcB6MPUB
# ---------------------------------
# Annoy index     : 772
# Image file name : AWo0UGybJbEilcB6MPUB
# Product id      : AWo0UGybJbEilcB6MPUB
# AWo0URm_AGTnQPR7q83W
# ---------------------------------
# Annoy index     : 773
# Image file name : AWo0URm_AGTnQPR7q83W
# Product id      : AWo0URm_AGTnQPR7q83W
# Step.1 - ANNOY index generation - Finished
# Step.2 - Similarity score calculation - Started

# %%
import json
with open('nearest_neighbors.json', 'w') as out:
    json.dump(named_nearest_neighbors, out)

# %%
image_mapping = []
for image in images:
    image_mapping.append({
      'image_path' : image['image_path'],
       'product_id': image['product_id']
    })
with open('image_mapping.txt', 'w') as out:
    #json.dump(images, out)
    out.write(str(image_mapping))

# %%
image_paths= glob.glob('C:\\Users\\Aakash Atnoorkar\\Documents\\ADM\\Final Project\\images\\imagesScraped\\*.npz')
product_list = []
for image in image_paths:
    product_list.append(ntpath.basename(image).split('.')[0])

# %%
with open('product_list.txt', 'w') as out:
    #json.dump(images, out)
    out.write(str(product_list))

# %%
sample_filtered = filtered_shoes[filtered_shoes['id'].isin(product_list)]

# %%
#sample_filtered.to_csv('sample_filtered.csv', index = True)
sample_filtered = sample_filtered.reset_index()
sample_filtered
# Out:
#        index                    id             brand  \
# 0          0  AVpe8Pi0ilAPnD_xRYTs  Fireside Casuals
# 1          1  AVpfNujoilAPnD_xXXc1          MUK LUKS
# 2          2  AVpfEFx41cnluZ0-dGzz              Daxx
# 3          3  AVpfOFMeilAPnD_xXe5b   Genuine Dickies
# 4          4  AVpfOFMeilAPnD_xXe5b   Genuine Dickies
# ...      ...                   ...               ...
# 60085  60085  AVpij_dBilAPnD_xFV8S       easy street
# 60086  60086  AVpij_dBilAPnD_xFV8S       easy street
# 60087  60087  AVpij_dBilAPnD_xFV8S       easy street
# 60088  60088  AVpij_dBilAPnD_xFV8S       easy street
# 60089  60089  AVpij_dBilAPnD_xFV8S       easy street
#
#                                                imageURLs  \
# 0      https://i5.walmartimages.com/asr/c55fed13-30ad...
# 1      https://i5.walmartimages.com/asr/481a1bfa-4e31...
# 2      https://i5.walmartimages.com/asr/9e7a8df0-cfc2...
# 3      https://i5.walmartimages.com/asr/4cc4b01e-434f...
# 4      https://i5.walmartimages.com/asr/4cc4b01e-434f...
# ...                                                  ...
# 60085  https://media.kohlsimg.com/is/image/kohls/2794...
# 60086  https://media.kohlsimg.com/is/image/kohls/2794...
# 60087  https://media.kohlsimg.com/is/image/kohls/2794...
# 60088  https://media.kohlsimg.com/is/image/kohls/2794...
# 60089  https://media.kohlsimg.com/is/image/kohls/2794...
#
#                                                     name  prices.amountMax  \
# 0                    Men's Camouflage Espadrille Slipper             20.00
# 1              Muk Luks Men's Fairisle Full Foot Slipper             14.99
# 2         Daxx Men's Topstitched Hardware Accent Loafers             29.99
# 3      Genuine Dickies Jobrated Maxx Waterproof Work ...             69.78
# 4      Genuine Dickies Jobrated Maxx Waterproof Work ...             69.78
# ...                                                  ...               ...
# 60085                 Easy Street Natara Women's Sandals             54.99
# 60086                 Easy Street Natara Women's Sandals             54.99
# 60087                 Easy Street Natara Women's Sandals             54.99
# 60088                 Easy Street Natara Women's Sandals             54.99
# 60089                 Easy Street Natara Women's Sandals             54.99
#
#        prices.amountMin prices.color                   prices.dateSeen  \
# 0                 20.00   Camouflage  2015-04-04 23:35:36.936000+00:00
# 1                 14.99         Java  2015-04-04 22:46:00.817000+00:00
# 2                 29.99        Black         2015-08-18 00:00:00+00:00
# 3                 69.78        Wheat         2015-10-18 00:00:00+00:00
# 4                 69.78        Wheat         2015-08-24 00:00:00+00:00
# ...                 ...          ...                               ...
# 60085             54.99        Black         2017-11-30 07:34:00+00:00
# 60086             54.99        Black         2017-11-27 11:53:00+00:00
# 60087             54.99        Black         2017-11-29 11:20:00+00:00
# 60088             54.99        Black         2017-11-26 14:21:00+00:00
# 60089             54.99        Black         2017-11-25 14:37:00+00:00
#
#        prices.size gender  dateDiff  avgPrice  \
# 0              8.0      M     318.0       0.0
# 1              5.0      M     318.0       0.0
# 2              7.5      M     183.0       0.0
# 3             10.5      M     122.0       0.0
# 4             13.0      M     177.0       0.0
# ...            ...    ...       ...       ...
# 60085          7.5      F     516.0       0.0
# 60086          7.5      F     519.0       0.0
# 60087          7.5      F     517.0       0.0
# 60088          7.5      F     520.0       0.0
# 60089          7.5      F     521.0       0.0
#
#                                                image_url
# 0      https://i5.walmartimages.com/asr/c55fed13-30ad...
# 1      https://i5.walmartimages.com/asr/481a1bfa-4e31...
# 2      https://i5.walmartimages.com/asr/9e7a8df0-cfc2...
# 3      https://i5.walmartimages.com/asr/4cc4b01e-434f...
# 4      https://i5.walmartimages.com/asr/4cc4b01e-434f...
# ...                                                  ...
# 60085  https://media.kohlsimg.com/is/image/kohls/2794...
# 60086  https://media.kohlsimg.com/is/image/kohls/2794...
# 60087  https://media.kohlsimg.com/is/image/kohls/2794...
# 60088  https://media.kohlsimg.com/is/image/kohls/2794...
# 60089  https://media.kohlsimg.com/is/image/kohls/2794...
#
# [60090 rows x 14 columns]

# %%
#sample_filtered = sample_filtered.drop(columns=['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.1.1'])
sample_filtered = sample_filtered.drop(columns=['index'])

# %%
sample_filtered.to_csv('sample_filtered.csv')

# %%
allfiles = glob.glob('C:\\Users\\Aakash Atnoorkar\\Documents\\ADM\\Final Project\\images\\imagesScraped\\*.npz')

success_images = []
for file_index, i in enumerate(allfiles):
    success_images.append(ntpath.basename(i).split('.')[0] + '.jpg')

# %%
column_names = ["similarity", "master_pi", "similar_pi"]

similarity_df = pd.DataFrame(columns = column_names)
similarity_df = similarity_df.append(named_nearest_neighbors)

# %%
similarity_df.to_csv('similarity_scores.csv')

# %%
import snowflake.connector

# %%
query = "SELECT SIMILAR_PI, MASTER_PI, SIMILARITY_SCORE FROM SIMILARITY_SCORES WHERE MASTER_PI = \'" + "AV-9hndsuC1rwyj_g2bb" + "\' AND SIMILARITY_SCORE!=1 ORDER BY SIMILARITY_SCORE DESC"
print(query)
results = curs.execute(query).fetchall()
# Out:
# SELECT SIMILAR_PI, MASTER_PI, SIMILARITY_SCORE FROM SIMILARITY_SCORES WHERE MASTER_PI = 'AV-9hndsuC1rwyj_g2bb' AND SIMILARITY_SCORE!=1 ORDER BY SIMILARITY_SCORE DESC

# %%
sim_products_score = []
for rec in results:
    sim_products_score.append(rec[0])

# %%
results = curs.execute(query).fetchall()
